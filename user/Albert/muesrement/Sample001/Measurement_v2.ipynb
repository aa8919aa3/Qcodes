# %% [markdown]
# # Initialization

# %% [markdown]
# ## Inport modules

# %%
# %matplotlib inline
import os, sys
import matplotlib.pyplot as plt
import numpy as np
from pprint import pprint
from tqdm import tqdm
from IPython.display import clear_output

from time import sleep, monotonic, time


import qcodes as qc
from qcodes import Parameter
from qcodes.dataset.plotting import plot_dataset, plot_by_id
from qcodes.utils.metadata import diff_param_values
from qcodes.instrument.specialized_parameters import ElapsedTimeParameter
from qcodes.dataset.measurements import Measurement

# sys.path.append('M:\\tnw\\ns\\qt\\2D Topo\\code\\qcodes')
sys.path.append('C:\\qcodes')
from sweeps_v2 import do1d, do2d, time_sweep, measure_until, do1d_until

import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\qcodes\sweeps_v2.py:85: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
#   (dyn_param, dyn_set)

# %%
fridge_name = 'BF1'
# %run ..\..\..\..\..\code\qcodes\init_fridge.py {fridge_name}
# %run C:\qcodes\init_fridge_v2.py {fridge_name}
# Out:
# [keithley_24(Keithley2400)] Snapshot: Could not update parameter: volt
# Connected to: KEITHLEY INSTRUMENTS DMM6500 (serial:04518052, firmware:1.7.7b) in 0.29s
# Connected to: KEITHLEY INSTRUMENTS INC. 2440 (serial:1225508, firmware:C30   Mar 17 2006 09:29:29/A02  /B/A) in 0.03s
# [keithley_24(Keithley2400)] Snapshot: Could not update parameter: curr
# [keithley_24(Keithley2400)] Snapshot: Could not update parameter: resistance
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# File C:\qcodes\init_fridge_v2.py:33
#      29     exec(open('../../../../../code/fridge_specific/init_CF1400.py').read())
#      30 elif fridge_name == 'BF1':
#      31 #     exec(open('../fridge_specific/init_BF1.py').read())
# ---> 33     exec(open('C:\\qcodes\\fridge_specific\\init_BF1_v2.py').read())
#      35 else:
#      36     print('Wrong fridge name!')
#
# File <string>:23
#
# File c:\Users\quant\anaconda3\envs\qcodes\Lib\site-packages\qcodes\instrument\instrument_meta.py:36, in InstrumentMeta.__call__(cls, *args, **kwargs)
#      31 def __call__(cls, *args: Any, **kwargs: Any) -> Any:
#      32     """
#      33     Overloads `type.__call__` to add code that runs only if __init__ completes
#      34     successfully.
#      35     """
# ---> 36     new_inst = super().__call__(*args, **kwargs)
#      37     is_abstract = new_inst._is_abstract()
#      38     if is_abstract:
#
# File c:\Users\quant\anaconda3\envs\qcodes\Lib\site-packages\qcodes\instrument_drivers\stanford_research\SR860.py:14, in SR860.__init__(self, name, address, reset, **kwargs)
#      11 def __init__(
#      12     self, name: str, address: str, reset: bool = False, **kwargs: str
#      13 ) -> None:
# ---> 14     super().__init__(name, address, max_frequency=500e3, reset=reset, **kwargs)
#
# File c:\Users\quant\anaconda3\envs\qcodes\Lib\site-packages\qcodes\instrument_drivers\stanford_research\SR86x.py:669, in SR86x.__init__(self, name, address, max_frequency, reset, **kwargs)
#     662 def __init__(
#     663         self,
#     664         name: str,
#    (...)
#     667         reset: bool = False,
#     668         **kwargs: Any):
# --> 669     super().__init__(name, address, terminator='\n', **kwargs)
#     670     self._max_frequency = max_frequency
#     671     # Reference commands
#
# File c:\Users\quant\anaconda3\envs\qcodes\Lib\site-packages\qcodes\instrument\visa.py:124, in VisaInstrument.__init__(self, name, address, timeout, terminator, device_clear, visalib, pyvisa_sim_file, **kwargs)
#     121 self._address = address
#     123 if device_clear:
# --> 124     self.device_clear()
#     126 self.set_terminator(terminator)
#     127 self.timeout.set(timeout)
#
# File c:\Users\quant\anaconda3\envs\qcodes\Lib\site-packages\qcodes\instrument\visa.py:202, in VisaInstrument.device_clear(self)
#     200     self.visa_handle.flush(flush_operation)
#     201 else:
# --> 202     self.visa_handle.clear()
#
# File c:\Users\quant\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\resource.py:382, in Resource.clear(self)
#     380 def clear(self) -> None:
#     381     """Clear this resource."""
# --> 382     self.visalib.clear(self.session)
#
# File c:\Users\quant\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\ctwrapper\functions.py:616, in clear(library, session)
#     598 def clear(library, session):
#     599     """Clears a device.
#     600
#     601     Corresponds to viClear function of the VISA library.
#    (...)
#     614
#     615     """
# --> 616     return library.viClear(session)
#
# File c:\Users\quant\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\ctwrapper\highlevel.py:226, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     223         # Set session back to a safe value
#     224         session = None
# --> 226 return self.handle_return_value(session, ret_value)
#
# File c:\Users\quant\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\highlevel.py:251, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     248     self._last_status_in_session[session] = rv
#     250 if rv < 0:
# --> 251     raise errors.VisaIOError(rv)
#     253 if rv in self.issue_warning_on:
#     254     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: VI_ERROR_NLISTENERS (-1073807265): No listeners condition is detected (both NRFD and NDAC are deasserted).

# %%
snapshot_of_station = station.snapshot()
pprint(snapshot_of_station)
# Out:
# {'components': {},
#  'config': None,
#  'instruments': {'keithley_24': {'__class__': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                  'address': 'GPIB0::22::INSTR',
#                                  'functions': {},
#                                  'label': 'keithley_24',
#                                  'name': 'keithley_24',
#                                  'parameters': {'IDN': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                         'full_name': 'keithley_24_IDN',
#                                                         'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                         'instrument_name': 'keithley_24',
#                                                         'inter_delay': 0,
#                                                         'label': 'IDN',
#                                                         'name': 'IDN',
#                                                         'post_delay': 0,
#                                                         'raw_value': {'firmware': 'C30   '
#                                                                                   'Mar '
#                                                                                   '17 '
#                                                                                   '2006 '
#                                                                                   '09:29:29/A02  '
#                                                                                   '/B/A',
#                                                                       'model': '2440',
#                                                                       'serial': '1225508',
#                                                                       'vendor': 'KEITHLEY '
#                                                                                 'INSTRUMENTS '
#                                                                                 'INC.'},
#                                                         'ts': '2024-05-20 '
#                                                               '20:20:56',
#                                                         'unit': '',
#                                                         'vals': '<Anything>',
#                                                         'value': {'firmware': 'C30   '
#                                                                               'Mar '
#                                                                               '17 '
#                                                                               '2006 '
#                                                                               '09:29:29/A02  '
#                                                                               '/B/A',
#                                                                   'model': '2440',
#                                                                   'serial': '1225508',
#                                                                   'vendor': 'KEITHLEY '
#                                                                             'INSTRUMENTS '
#                                                                             'INC.'}},
#                                                 'compliancei': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                 'full_name': 'keithley_24_compliancei',
#                                                                 'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                                 'instrument_name': 'keithley_24',
#                                                                 'inter_delay': 0,
#                                                                 'label': 'Current '
#                                                                          'Compliance',
#                                                                 'name': 'compliancei',
#                                                                 'post_delay': 0,
#                                                                 'raw_value': '1.000000E-01',
#                                                                 'ts': '2024-05-20 '
#                                                                       '20:20:56',
#                                                                 'unit': '',
#                                                                 'value': 0.1},
#                                                 'compliancev': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                 'full_name': 'keithley_24_compliancev',
#                                                                 'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                                 'instrument_name': 'keithley_24',
#                                                                 'inter_delay': 0,
#                                                                 'label': 'Voltage '
#                                                                          'Compliance',
#                                                                 'name': 'compliancev',
#                                                                 'post_delay': 0,
#                                                                 'raw_value': '1.050000E+01',
#                                                                 'ts': '2024-05-20 '
#                                                                       '20:20:56',
#                                                                 'unit': '',
#                                                                 'value': 10.5},
#                                                 'curr': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                          'full_name': 'keithley_24_curr',
#                                                          'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                          'instrument_name': 'keithley_24',
#                                                          'inter_delay': 0,
#                                                          'label': 'Current',
#                                                          'name': 'curr',
#                                                          'post_delay': 0,
#                                                          'raw_value': None,
#                                                          'ts': None,
#                                                          'unit': 'A',
#                                                          'value': None},
#                                                 'mode': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                          'full_name': 'keithley_24_mode',
#                                                          'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                          'instrument_name': 'keithley_24',
#                                                          'inter_delay': 0,
#                                                          'label': 'Mode',
#                                                          'name': 'mode',
#                                                          'post_delay': 0,
#                                                          'raw_value': 'VOLT',
#                                                          'ts': '2024-05-20 '
#                                                                '20:20:56',
#                                                          'unit': '',
#                                                          'vals': '<Enum: '
#                                                                  "{'CURR', "
#                                                                  "'VOLT'}>",
#                                                          'value': 'VOLT'},
#                                                 'nplci': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                           'full_name': 'keithley_24_nplci',
#                                                           'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                           'instrument_name': 'keithley_24',
#                                                           'inter_delay': 0,
#                                                           'label': 'Current '
#                                                                    'integration '
#                                                                    'time',
#                                                           'name': 'nplci',
#                                                           'post_delay': 0,
#                                                           'raw_value': '1.00',
#                                                           'ts': '2024-05-20 '
#                                                                 '20:20:56',
#                                                           'unit': '',
#                                                           'value': 1.0},
#                                                 'nplcv': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                           'full_name': 'keithley_24_nplcv',
#                                                           'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                           'instrument_name': 'keithley_24',
#                                                           'inter_delay': 0,
#                                                           'label': 'Voltage '
#                                                                    'integration '
#                                                                    'time',
#                                                           'name': 'nplcv',
#                                                           'post_delay': 0,
#                                                           'raw_value': '1.00',
#                                                           'ts': '2024-05-20 '
#                                                                 '20:20:56',
#                                                           'unit': '',
#                                                           'value': 1.0},
#                                                 'output': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                            'full_name': 'keithley_24_output',
#                                                            'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                            'instrument_name': 'keithley_24',
#                                                            'inter_delay': 0,
#                                                            'label': 'output',
#                                                            'name': 'output',
#                                                            'post_delay': 0,
#                                                            'raw_value': '0',
#                                                            'ts': '2024-05-20 '
#                                                                  '20:20:56',
#                                                            'unit': '',
#                                                            'val_mapping': OrderedDict([('On',
#                                                                                         '1'),
#                                                                                        ('ON',
#                                                                                         '1'),
#                                                                                        ('on',
#                                                                                         '1'),
#                                                                                        ('1',
#                                                                                         '1'),
#                                                                                        (True,
#                                                                                         '1'),
#                                                                                        ('Off',
#                                                                                         '0'),
#                                                                                        ('OFF',
#                                                                                         '0'),
#                                                                                        ('off',
#                                                                                         '0'),
#                                                                                        ('0',
#                                                                                         '0'),
#                                                                                        (False,
#                                                                                         '0')]),
#                                                            'vals': '<Enum: '
#                                                                    '{False, '
#                                                                    "True, '0', "
#                                                                    "'1', 'On', "
#                                                                    "'OFF', "
#                                                                    "'off', "
#                                                                    "'ON', "
#                                                                    "'on', "
#                                                                    "'Off'}>",
#                                                            'value': False},
#                                                 'rangei': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                            'full_name': 'keithley_24_rangei',
#                                                            'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                            'instrument_name': 'keithley_24',
#                                                            'inter_delay': 0,
#                                                            'label': 'Current '
#                                                                     'range',
#                                                            'name': 'rangei',
#                                                            'post_delay': 0,
#                                                            'raw_value': '1.050000E-01',
#                                                            'ts': '2024-05-20 '
#                                                                  '20:20:56',
#                                                            'unit': '',
#                                                            'value': 0.105},
#                                                 'rangev': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                            'full_name': 'keithley_24_rangev',
#                                                            'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                            'instrument_name': 'keithley_24',
#                                                            'inter_delay': 0,
#                                                            'label': 'Voltage '
#                                                                     'range',
#                                                            'name': 'rangev',
#                                                            'post_delay': 0,
#                                                            'raw_value': '10.50',
#                                                            'ts': '2024-05-20 '
#                                                                  '20:20:56',
#                                                            'unit': '',
#                                                            'value': 10.5},
#                                                 'resistance': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                'full_name': 'keithley_24_resistance',
#                                                                'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                                'instrument_name': 'keithley_24',
#                                                                'inter_delay': 0,
#                                                                'label': 'Resistance',
#                                                                'name': 'resistance',
#                                                                'post_delay': 0,
#                                                                'raw_value': None,
#                                                                'ts': None,
#                                                                'unit': 'Ohm',
#                                                                'value': None},
#                                                 'sense': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                           'full_name': 'keithley_24_sense',
#                                                           'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                           'instrument_name': 'keithley_24',
#                                                           'inter_delay': 0,
#                                                           'label': 'Sense mode',
#                                                           'name': 'sense',
#                                                           'post_delay': 0,
#                                                           'raw_value': '"CURR:DC"',
#                                                           'ts': '2024-05-20 '
#                                                                 '20:20:56',
#                                                           'unit': '',
#                                                           'vals': '<Strings>',
#                                                           'value': '"CURR:DC"'},
#                                                 'timeout': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                             'full_name': 'keithley_24_timeout',
#                                                             'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                             'instrument_name': 'keithley_24',
#                                                             'inter_delay': 0,
#                                                             'label': 'timeout',
#                                                             'name': 'timeout',
#                                                             'post_delay': 0,
#                                                             'raw_value': 10.0,
#                                                             'ts': '2024-05-20 '
#                                                                   '20:20:56',
#                                                             'unit': 's',
#                                                             'vals': '<MultiType: '
#                                                                     'Numbers '
#                                                                     'v>=0, '
#                                                                     'Enum: '
#                                                                     '{None}>',
#                                                             'value': 10.0},
#                                                 'volt': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                          'full_name': 'keithley_24_volt',
#                                                          'instrument': 'qcodes.instrument_drivers.Keithley.Keithley_2400.Keithley2400',
#                                                          'instrument_name': 'keithley_24',
#                                                          'inter_delay': 0,
#                                                          'label': 'Voltage',
#                                                          'name': 'volt',
#                                                          'post_delay': 0,
#                                                          'raw_value': None,
#                                                          'ts': None,
#                                                          'unit': 'V',
#                                                          'value': None}},
#                                  'read_terminator': '\n',
#                                  'submodules': {},
#                                  'terminator': '\n',
#                                  'timeout': 10.0,
#                                  'write_terminator': '\n'},
#                  'keithley_K1': {'__class__': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                  'address': 'GPIB0::6::INSTR',
#                                  'functions': {},
#                                  'label': 'keithley_K1',
#                                  'name': 'keithley_K1',
#                                  'parameters': {'IDN': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                         'full_name': 'keithley_K1_IDN',
#                                                         'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                         'instrument_name': 'keithley_K1',
#                                                         'inter_delay': 0,
#                                                         'label': 'IDN',
#                                                         'name': 'IDN',
#                                                         'post_delay': 0,
#                                                         'raw_value': {'firmware': '1.7.7b',
#                                                                       'model': 'DMM6500',
#                                                                       'serial': '04518052',
#                                                                       'vendor': 'KEITHLEY '
#                                                                                 'INSTRUMENTS'},
#                                                         'ts': '2024-05-20 '
#                                                               '20:20:55',
#                                                         'unit': '',
#                                                         'vals': '<Anything>',
#                                                         'value': {'firmware': '1.7.7b',
#                                                                   'model': 'DMM6500',
#                                                                   'serial': '04518052',
#                                                                   'vendor': 'KEITHLEY '
#                                                                             'INSTRUMENTS'}},
#                                                 'amplitude': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                               'full_name': 'keithley_K1_amplitude',
#                                                               'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                               'instrument_name': 'keithley_K1',
#                                                               'inter_delay': 0,
#                                                               'label': 'amplitude',
#                                                               'name': 'amplitude',
#                                                               'post_delay': 0,
#                                                               'raw_value': 1.317061e-05,
#                                                               'ts': '2024-05-20 '
#                                                                     '20:20:56',
#                                                               'unit': 'a.u.',
#                                                               'value': 1.317061e-05},
#                                                 'auto_range_enabled': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                        'full_name': 'keithley_K1_auto_range_enabled',
#                                                                        'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                        'instrument_name': 'keithley_K1',
#                                                                        'inter_delay': 0,
#                                                                        'label': 'auto_range_enabled',
#                                                                        'name': 'auto_range_enabled',
#                                                                        'post_delay': 0,
#                                                                        'raw_value': True,
#                                                                        'ts': '2024-05-20 '
#                                                                              '20:20:55',
#                                                                        'unit': '',
#                                                                        'vals': '<Boolean>',
#                                                                        'value': True},
#                                                 'averaging_count': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                     'full_name': 'keithley_K1_averaging_count',
#                                                                     'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                     'instrument_name': 'keithley_K1',
#                                                                     'inter_delay': 0,
#                                                                     'label': 'averaging_count',
#                                                                     'name': 'averaging_count',
#                                                                     'post_delay': 0,
#                                                                     'raw_value': 10,
#                                                                     'ts': '2024-05-20 '
#                                                                           '20:20:55',
#                                                                     'unit': '',
#                                                                     'vals': '<Ints '
#                                                                             '1<=v<=100>',
#                                                                     'value': 10},
#                                                 'averaging_enabled': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                       'full_name': 'keithley_K1_averaging_enabled',
#                                                                       'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                       'instrument_name': 'keithley_K1',
#                                                                       'inter_delay': 0,
#                                                                       'label': 'averaging_enabled',
#                                                                       'name': 'averaging_enabled',
#                                                                       'post_delay': 0,
#                                                                       'raw_value': True,
#                                                                       'ts': '2024-05-20 '
#                                                                             '20:20:55',
#                                                                       'unit': '',
#                                                                       'vals': '<Boolean>',
#                                                                       'value': True},
#                                                 'averaging_type': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                    'full_name': 'keithley_K1_averaging_type',
#                                                                    'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                    'instrument_name': 'keithley_K1',
#                                                                    'inter_delay': 0,
#                                                                    'label': 'averaging_type',
#                                                                    'name': 'averaging_type',
#                                                                    'post_delay': 0,
#                                                                    'raw_value': 'repeat',
#                                                                    'ts': '2024-05-20 '
#                                                                          '20:20:55',
#                                                                    'unit': '',
#                                                                    'vals': '<Enum: '
#                                                                            "{'repeat', "
#                                                                            "'moving'}>",
#                                                                    'value': 'repeat'},
#                                                 'digits': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                            'full_name': 'keithley_K1_digits',
#                                                            'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                            'instrument_name': 'keithley_K1',
#                                                            'inter_delay': 0,
#                                                            'label': 'digits',
#                                                            'name': 'digits',
#                                                            'post_delay': 0,
#                                                            'raw_value': '6',
#                                                            'ts': '2024-05-20 '
#                                                                  '20:20:55',
#                                                            'unit': '',
#                                                            'vals': '<Ints '
#                                                                    '4<=v<=7>',
#                                                            'value': 6},
#                                                 'display_backlight': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                       'full_name': 'keithley_K1_display_backlight',
#                                                                       'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                       'instrument_name': 'keithley_K1',
#                                                                       'inter_delay': 0,
#                                                                       'label': 'display_backlight',
#                                                                       'name': 'display_backlight',
#                                                                       'post_delay': 0,
#                                                                       'raw_value': 'ON50',
#                                                                       'ts': '2024-05-20 '
#                                                                             '20:20:55',
#                                                                       'unit': '',
#                                                                       'val_mapping': {'Blackout': 'BLACkout',
#                                                                                       'Off': 'OFF',
#                                                                                       'On 100': 'ON100',
#                                                                                       'On 25': 'ON25',
#                                                                                       'On 50': 'ON50',
#                                                                                       'On 75': 'ON75'},
#                                                                       'vals': '<Enum: '
#                                                                               "{'On "
#                                                                               "100', "
#                                                                               "'On "
#                                                                               "50', "
#                                                                               "'On "
#                                                                               "75', "
#                                                                               "'On "
#                                                                               "25', "
#                                                                               "'Off', "
#                                                                               "'Blackout'}>",
#                                                                       'value': 'On '
#                                                                                '50'},
#                                                 'mode': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                          'full_name': 'keithley_K1_mode',
#                                                          'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                          'instrument_name': 'keithley_K1',
#                                                          'inter_delay': 0,
#                                                          'label': 'mode',
#                                                          'name': 'mode',
#                                                          'post_delay': 0,
#                                                          'raw_value': 'VOLT:DC',
#                                                          'ts': '2024-05-20 '
#                                                                '20:20:55',
#                                                          'unit': '',
#                                                          'val_mapping': {'2w resistance': 'RES',
#                                                                          '4w resistance': 'FRES',
#                                                                          'ac current': 'CURR:AC',
#                                                                          'ac voltage': 'VOLT:AC',
#                                                                          'dc current': 'CURR:DC',
#                                                                          'dc voltage': 'VOLT:DC',
#                                                                          'frequency': 'FREQ',
#                                                                          'temperature': 'TEMP'},
#                                                          'vals': "<Enum: {'ac "
#                                                                  "current', "
#                                                                  "'dc "
#                                                                  "current', "
#                                                                  "'dc "
#                                                                  "voltage', "
#                                                                  "'2w "
#                                                                  "resistance', "
#                                                                  "'frequency', "
#                                                                  "'4w "
#                                                                  "resistance', "
#                                                                  "'temperature', "
#                                                                  "'ac "
#                                                                  "voltage'}>",
#                                                          'value': 'dc voltage'},
#                                                 'nplc': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                          'full_name': 'keithley_K1_nplc',
#                                                          'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                          'instrument_name': 'keithley_K1',
#                                                          'inter_delay': 0,
#                                                          'label': 'nplc',
#                                                          'name': 'nplc',
#                                                          'post_delay': 0,
#                                                          'raw_value': 1.0,
#                                                          'ts': '2024-05-20 '
#                                                                '20:20:55',
#                                                          'unit': '',
#                                                          'vals': '<Numbers '
#                                                                  '0.01<=v<=10>',
#                                                          'value': 1.0},
#                                                 'range': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                           'full_name': 'keithley_K1_range',
#                                                           'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                           'instrument_name': 'keithley_K1',
#                                                           'inter_delay': 0,
#                                                           'label': 'range',
#                                                           'name': 'range',
#                                                           'post_delay': 0,
#                                                           'raw_value': 0.1,
#                                                           'ts': '2024-05-20 '
#                                                                 '20:20:55',
#                                                           'unit': '',
#                                                           'vals': '<Numbers>',
#                                                           'value': 0.1},
#                                                 'timeout': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                             'full_name': 'keithley_K1_timeout',
#                                                             'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                             'instrument_name': 'keithley_K1',
#                                                             'inter_delay': 0,
#                                                             'label': 'timeout',
#                                                             'name': 'timeout',
#                                                             'post_delay': 0,
#                                                             'raw_value': 10.0,
#                                                             'ts': '2024-05-20 '
#                                                                   '20:20:56',
#                                                             'unit': 's',
#                                                             'vals': '<MultiType: '
#                                                                     'Numbers '
#                                                                     'v>=0, '
#                                                                     'Enum: '
#                                                                     '{None}>',
#                                                             'value': 10.0},
#                                                 'trigger1_delay': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                    'full_name': 'keithley_K1_trigger1_delay',
#                                                                    'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                    'instrument_name': 'keithley_K1',
#                                                                    'inter_delay': 0,
#                                                                    'label': 'trigger1_delay',
#                                                                    'name': 'trigger1_delay',
#                                                                    'post_delay': 0,
#                                                                    'raw_value': '1E-05',
#                                                                    'ts': '2024-05-20 '
#                                                                          '20:20:55',
#                                                                    'unit': 's',
#                                                                    'vals': '<Numbers '
#                                                                            '0<=v<=999999.999>',
#                                                                    'value': 1e-05},
#                                                 'trigger1_source': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                     'full_name': 'keithley_K1_trigger1_source',
#                                                                     'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                     'instrument_name': 'keithley_K1',
#                                                                     'inter_delay': 0,
#                                                                     'label': 'trigger1_source',
#                                                                     'name': 'trigger1_source',
#                                                                     'post_delay': 0,
#                                                                     'raw_value': 'NONE',
#                                                                     'ts': '2024-05-20 '
#                                                                           '20:20:55',
#                                                                     'unit': '',
#                                                                     'val_mapping': {'bus': 'COMM',
#                                                                                     'external': 'EXT',
#                                                                                     'front-panel': 'DISP',
#                                                                                     'immediate': 'NONE',
#                                                                                     'notify1': 'NOT1',
#                                                                                     'notify2': 'NOT2',
#                                                                                     'notify3': 'NOT3',
#                                                                                     'timer1': 'TIM1',
#                                                                                     'timer2': 'TIM2',
#                                                                                     'timer3': 'TIM3',
#                                                                                     'timer4': 'TIM4'},
#                                                                     'vals': '<Enum: '
#                                                                             "{'notify1', "
#                                                                             "'immediate', "
#                                                                             "'external', "
#                                                                             "'bus', "
#                                                                             "'front-panel', "
#                                                                             "'timer4', "
#                                                                             "'timer2', "
#                                                                             "'notify2', "
#                                                                             "'timer3', "
#                                                                             "'timer1', "
#                                                                             "'notify3'}>",
#                                                                     'value': 'immediate'},
#                                                 'trigger2_delay': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                    'full_name': 'keithley_K1_trigger2_delay',
#                                                                    'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                    'instrument_name': 'keithley_K1',
# ...
#                                                                           '20:20:56',
#                                                                     'unit': '',
#                                                                     'val_mapping': {'bus': 'COMM',
#                                                                                     'external': 'EXT',
#                                                                                     'front-panel': 'DISP',
#                                                                                     'immediate': 'NONE',
#                                                                                     'notify1': 'NOT1',
#                                                                                     'notify2': 'NOT2',
#                                                                                     'notify3': 'NOT3',
#                                                                                     'timer1': 'TIM1',
#                                                                                     'timer2': 'TIM2',
#                                                                                     'timer3': 'TIM3',
#                                                                                     'timer4': 'TIM4'},
#                                                                     'vals': '<Enum: '
#                                                                             "{'notify1', "
#                                                                             "'immediate', "
#                                                                             "'external', "
#                                                                             "'bus', "
#                                                                             "'front-panel', "
#                                                                             "'timer4', "
#                                                                             "'timer2', "
#                                                                             "'notify2', "
#                                                                             "'timer3', "
#                                                                             "'timer1', "
#                                                                             "'notify3'}>",
#                                                                     'value': 'immediate'},
#                                                 'trigger3_delay': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                    'full_name': 'keithley_K1_trigger3_delay',
#                                                                    'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                    'instrument_name': 'keithley_K1',
#                                                                    'inter_delay': 0,
#                                                                    'label': 'trigger3_delay',
#                                                                    'name': 'trigger3_delay',
#                                                                    'post_delay': 0,
#                                                                    'raw_value': '1E-05',
#                                                                    'ts': '2024-05-20 '
#                                                                          '20:20:56',
#                                                                    'unit': 's',
#                                                                    'vals': '<Numbers '
#                                                                            '0<=v<=999999.999>',
#                                                                    'value': 1e-05},
#                                                 'trigger3_source': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                     'full_name': 'keithley_K1_trigger3_source',
#                                                                     'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                     'instrument_name': 'keithley_K1',
#                                                                     'inter_delay': 0,
#                                                                     'label': 'trigger3_source',
#                                                                     'name': 'trigger3_source',
#                                                                     'post_delay': 0,
#                                                                     'raw_value': 'NONE',
#                                                                     'ts': '2024-05-20 '
#                                                                           '20:20:56',
#                                                                     'unit': '',
#                                                                     'val_mapping': {'bus': 'COMM',
#                                                                                     'external': 'EXT',
#                                                                                     'front-panel': 'DISP',
#                                                                                     'immediate': 'NONE',
#                                                                                     'notify1': 'NOT1',
#                                                                                     'notify2': 'NOT2',
#                                                                                     'notify3': 'NOT3',
#                                                                                     'timer1': 'TIM1',
#                                                                                     'timer2': 'TIM2',
#                                                                                     'timer3': 'TIM3',
#                                                                                     'timer4': 'TIM4'},
#                                                                     'vals': '<Enum: '
#                                                                             "{'notify1', "
#                                                                             "'immediate', "
#                                                                             "'external', "
#                                                                             "'bus', "
#                                                                             "'front-panel', "
#                                                                             "'timer4', "
#                                                                             "'timer2', "
#                                                                             "'notify2', "
#                                                                             "'timer3', "
#                                                                             "'timer1', "
#                                                                             "'notify3'}>",
#                                                                     'value': 'immediate'},
#                                                 'trigger4_delay': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                    'full_name': 'keithley_K1_trigger4_delay',
#                                                                    'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                    'instrument_name': 'keithley_K1',
#                                                                    'inter_delay': 0,
#                                                                    'label': 'trigger4_delay',
#                                                                    'name': 'trigger4_delay',
#                                                                    'post_delay': 0,
#                                                                    'raw_value': '1E-05',
#                                                                    'ts': '2024-05-20 '
#                                                                          '20:20:56',
#                                                                    'unit': 's',
#                                                                    'vals': '<Numbers '
#                                                                            '0<=v<=999999.999>',
#                                                                    'value': 1e-05},
#                                                 'trigger4_source': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                     'full_name': 'keithley_K1_trigger4_source',
#                                                                     'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                     'instrument_name': 'keithley_K1',
#                                                                     'inter_delay': 0,
#                                                                     'label': 'trigger4_source',
#                                                                     'name': 'trigger4_source',
#                                                                     'post_delay': 0,
#                                                                     'raw_value': 'NONE',
#                                                                     'ts': '2024-05-20 '
#                                                                           '20:20:56',
#                                                                     'unit': '',
#                                                                     'val_mapping': {'bus': 'COMM',
#                                                                                     'external': 'EXT',
#                                                                                     'front-panel': 'DISP',
#                                                                                     'immediate': 'NONE',
#                                                                                     'notify1': 'NOT1',
#                                                                                     'notify2': 'NOT2',
#                                                                                     'notify3': 'NOT3',
#                                                                                     'timer1': 'TIM1',
#                                                                                     'timer2': 'TIM2',
#                                                                                     'timer3': 'TIM3',
#                                                                                     'timer4': 'TIM4'},
#                                                                     'vals': '<Enum: '
#                                                                             "{'notify1', "
#                                                                             "'immediate', "
#                                                                             "'external', "
#                                                                             "'bus', "
#                                                                             "'front-panel', "
#                                                                             "'timer4', "
#                                                                             "'timer2', "
#                                                                             "'notify2', "
#                                                                             "'timer3', "
#                                                                             "'timer1', "
#                                                                             "'notify3'}>",
#                                                                     'value': 'immediate'},
#                                                 'trigger_count': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                   'full_name': 'keithley_K1_trigger_count',
#                                                                   'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                   'instrument_name': 'keithley_K1',
#                                                                   'inter_delay': 0,
#                                                                   'label': 'trigger_count',
#                                                                   'name': 'trigger_count',
#                                                                   'post_delay': 0,
#                                                                   'raw_value': '1',
#                                                                   'ts': '2024-05-20 '
#                                                                         '20:20:55',
#                                                                   'unit': '',
#                                                                   'vals': '<MultiType: '
#                                                                           'Ints '
#                                                                           '1<=v<=9999, '
#                                                                           'Enum: '
#                                                                           "{'maximum', "
#                                                                           "'inf', "
#                                                                           "'default', "
#                                                                           "'minimum'}>",
#                                                                   'value': 1},
#                                                 'trigger_timer': {'__class__': 'qcodes.parameters.parameter.Parameter',
#                                                                   'full_name': 'keithley_K1_trigger_timer',
#                                                                   'instrument': 'qcodes.instrument_drivers.tektronix.Keithley_6500.Keithley_6500',
#                                                                   'instrument_name': 'keithley_K1',
#                                                                   'inter_delay': 0,
#                                                                   'label': 'trigger_timer',
#                                                                   'name': 'trigger_timer',
#                                                                   'post_delay': 0,
#                                                                   'raw_value': '0',
#                                                                   'ts': '2024-05-20 '
#                                                                         '20:20:56',
#                                                                   'unit': 's',
#                                                                   'vals': '<Numbers '
#                                                                           '0<=v<=999999.999>',
#                                                                   'value': 0.0}},
#                                  'read_terminator': '\n',
#                                  'submodules': {},
#                                  'terminator': '\n',
#                                  'timeout': 10.0,
#                                  'write_terminator': '\n'}},
#  'parameters': {}}

# %% [markdown]
# ## Keithley 2440

# %% [markdown]
# ### sensitive check

# %%
keithley_24.mode('VOLT')
keithley_24.mode()
# Out:
# 'VOLT'

# %%
keithley_24.output(1) # output on
keithley_24.rangev(10)
keithley_24.volt(0)
keithley_24.compliancei(100e-3)
sleep(1)
v_read=keithley_K1.amplitude()
keithley_24.output(0) #output off
print(v_read)
# Out:
# -4.723676e-06

# %% [markdown]
# ## TG 2400

# %%
keithley_19.output(1) # output on
keithley_19.rangev(22)
keithley_19.volt(0)
keithley_19.compliancei(100e-3)
# keithley_24.output(0) #output off
sleep(1)
v_read=keithley_2.amplitude()
print(v_read)

# %%
keithley_19.volt(1)
keithley_19.output(0) #output off

# %%
keithley_19.rangev(22)
keithley_19.rangev()

# %% [markdown]
# #  Database initialisation

# %%
reuse = True
# %run C:\qcodes\init_database_v2.py {reuse}
# Out:
# Using existing database file:
# c:\qcodes\personal_scripts\Albert\Albert_2024-05-20_01.db

# %% [markdown]
# # Scaled parameters

# %%
from qcodes import ManualParameter, ScaledParameter

# %% [markdown]
# ## Defining scaled parameters

# %%
Irange = Parameter('Irange', label='current range', unit='', set_cmd=None, get_cmd=None)
Vrange = Parameter('Vrange', label='voltage range', unit='', set_cmd=None, get_cmd=None)
TGrange = Parameter('TGrange', label='Top gate range', unit='', set_cmd=None, get_cmd=None)

#division paraemtrs required for simplier update: they used as an argument for scaled paraemtrs of sorce instruments

# Irange_division = Parameter('Irange_division', 
#                             label='scaled current range', unit='', 
#                             set_cmd=None, get_cmd=lambda : 100 / Irange())

Irange_division = Parameter('Irange_division', 
                            label='scaled current range', unit='', 
                            set_cmd=None, get_cmd=lambda : 1 / Irange())

Vrange_division = Parameter('Vrange_division', 
                            label='scaled voltage range', unit='', 
                            set_cmd=None, get_cmd=lambda : 100 / Vrange())

TGrange_division = Parameter('TGrange_division', 
                             label='scaled Top gate range', unit='', 
                             set_cmd=None, get_cmd=lambda : 1 / TGrange())

Irange_AC_division = Parameter('Irange_AC_division', 
                               label='scaled current range for lockin', unit='', 
                               set_cmd=None, get_cmd=lambda : 1000 / Irange())

Vrange_AC_division = Parameter('Vrange_AC_division', 
                               label='scaled voltage range for lockin', unit='', 
                               set_cmd=None, get_cmd=lambda : 1000 / Vrange())

Gain_K1 = Parameter('Gain_K1', label='Gain K1', unit='', set_cmd=None, get_cmd=None)
Gain_K2 = Parameter('Gain_K2', label='Gain K2', unit='', set_cmd=None, get_cmd=None)
Gain_L1 = Parameter('Gain_L1', label='Gain L1', unit='', set_cmd=None, get_cmd=None)
Gain_L2 = Parameter('Gain_L2', label='Gain L2', unit='', set_cmd=None, get_cmd=None)

#Add components
station.add_component(Irange)
station.add_component(Vrange)
station.add_component(TGrange)

station.add_component(Irange_division)
station.add_component(Vrange_division)
station.add_component(TGrange_division)

station.add_component(Irange_AC_division)
station.add_component(Vrange_AC_division)
                             
station.add_component(Gain_K1)
station.add_component(Gain_K2)
station.add_component(Gain_L1)
station.add_component(Gain_L2)
# Out:
# 'Gain_L2'

# %% [markdown]
# ## Parameters - update here during measuerements

# %%
Irange.set(1e-6) #Unit Amp V=IR, 1V= 1e-6 x 1MOhm=1e-7 x 10MOhm
Vrange.set(10) ## need to be sync with K213 range #Unit Volt
TGrange.set(1) #Unit Volt
Gain_K1.set(100)
Gain_K2.set(100)
# Gain_K3.set(1e2)
Gain_L1.set(Gain_K1())
Gain_L2.set(Gain_K2())
#division parameters are updated automatically

# %%
keithley_24.nplcv
# Out:
# <qcodes.parameters.parameter.Parameter: nplcv at 2625100779088>

# %% [markdown]
# ## DC parameters

# %%
appl_current = ScaledParameter(keithley_24.volt, division = Irange_division, name = 'appl_current', unit = 'A')

#appl_TG = ScaledParameter(keithley_19.volt, division = TGrange_division, name = 'appl_TG', unit = 'V')

meas_voltage_K1 = ScaledParameter(keithley_K1.amplitude, division = Gain_K1, name = 'meas_voltage_K1', unit = 'V')
# meas_voltage_K2 = ScaledParameter(keithley_K2.amplitude, division = Gain_K2, name = 'meas_voltage_K2', unit = 'V')

# meas_leakage = ScaledParameter(keithley_K2.amplitude, division = Gain_K2, name = 'meas_leakage', unit = 'A')

meas_current_K1 = ScaledParameter(keithley_K1.amplitude, division = Gain_K1, name = 'meas_current_K1', unit = 'A')
# meas_current_K2 = ScaledParameter(keithley_K2.amplitude, division = Gain_K2, name = 'meas_current_K2', unit = 'A')

station.add_component(appl_current)
# station.add_component(appl_voltage)
#station.add_component(appl_TG)

station.add_component(meas_voltage_K1)
# station.add_component(meas_voltage_K2)

# station.add_component(meas_leakage)

station.add_component(meas_current_K1)
# station.add_component(meas_current_K2)
# Out:
# 'meas_current_K1'

# %%
keithley_24.output(0)
appl_current(0)
sleep(1)
# meas_voltage_K2()

# %% [markdown]
# ##  AC parameters

# %%
appl_current_AC = ScaledParameter(lockin_1.amplitude, division = Irange_AC_division, name = 'appl_current_AC', unit = 'A')
appl_voltage_AC = ScaledParameter(lockin_1.amplitude, division = Vrange_AC_division, name = 'appl_voltage_AC', unit = 'V')

station.add_component(appl_current_AC)
station.add_component(appl_voltage_AC)

meas_voltage_AC_L1 = ScaledParameter(lockin_1.X, division = Gain_L1, name = 'meas_voltage_Lockin1', unit = 'V')
meas_current_AC_L1 = ScaledParameter(lockin_1.X, division = Gain_L1, name = 'meas_current_Lockin1', unit = 'A')
meas_phase_AC_L1 = ScaledParameter(lockin_1.P, division = 1, name = 'meas_phase_Lockin1', unit = 'degree')


# meas_voltage_AC_L2 = ScaledParameter(lockin_2.X, division = Gain_L2, name = 'meas_voltage_Lockin2', unit = 'V')
# meas_current_AC_L2 = ScaledParameter(lockin_2.X, division = Gain_L2, name = 'meas_current_Lockin2', unit = 'A')
# meas_phase_AC_L2 = ScaledParameter(lockin_2.P, division = 1, name = 'meas_phase_Lockin1', unit = 'degree')

station.add_component(meas_voltage_AC_L1)
station.add_component(meas_current_AC_L1)
station.add_component(meas_phase_AC_L1)

# station.add_component(meas_voltage_AC_L2)
# station.add_component(meas_current_AC_L2)

meas_voltage_AC_L1_R = ScaledParameter(lockin_1.R, division = Gain_L1, name = 'meas_voltage_R_Lockin1', unit = 'V')
# meas_voltage_AC_L2_R = ScaledParameter(lockin_2.R, division = Gain_L2, name = 'meas_voltage_R_Lockin2', unit = 'V')

station.add_component(meas_voltage_AC_L1_R)
# station.add_component(meas_voltage_AC_L2_R)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 appl_current_AC = ScaledParameter(lockin_1.amplitude, division = Irange_AC_division, name = 'appl_current_AC', unit = 'A')
#       2 appl_voltage_AC = ScaledParameter(lockin_1.amplitude, division = Vrange_AC_division, name = 'appl_voltage_AC', unit = 'V')
#       4 station.add_component(appl_current_AC)
#
# NameError: name 'lockin_1' is not defined

# %%
meas_voltage_AC_L1_P = ScaledParameter(lockin_1.P, division = 1, name = 'meas_voltage_Lockin1_P', unit = 'degree')
meas_current_AC_L1_P = ScaledParameter(lockin_1.P, division = 1, name = 'meas_current_Lockin1_P', unit = 'degree')

# meas_voltage_AC_L2_P = ScaledParameter(lockin_2.P, division = 1, name = 'meas_voltage_Lockin2_P', unit = 'degree')
# meas_current_AC_L2_P = ScaledParameter(lockin_2.P, division = 1, name = 'meas_current_Lockin2_P', unit = 'degree')

station.add_component(meas_voltage_AC_L1_P)
station.add_component(meas_current_AC_L1_P)

# station.add_component(meas_voltage_AC_L2_P)
# station.add_component(meas_current_AC_L2_P)

# %% [markdown]
# ## Another useful example: magnet using dac (Janis)

# %% [markdown]
# >2231.2 G per A => 0.22312 T per A<br>
# I source 10mA per V => 1e-5 A per 1mV<br>
# result: 0.22312 T/A * 1e-5 A/mV

# %%
# def get_R_from_IV(dataid):
#     dataset = qc.load_by_id(dataid)
#     voltage = dataset.get_parameter_data()['meas_voltage_K2']['meas_voltage_K2']
#     current = dataset.get_parameter_data()['meas_voltage_K2']['appl_current']
#     fit_values = np.polyfit(current,voltage,1)
    
#     return fit_values[0]

def get_R_from_IV_2(dataid):
    dataset = qc.load_by_id(dataid)
    voltage = dataset.get_parameter_data()['meas_voltage_K2']['meas_voltage_K2']
    current = dataset.get_parameter_data()['meas_voltage_K2']['appl_current']
    fit_values = np.polyfit(current,voltage,1)

    return fit_values[0]

def get_R_from_IV(dataid):
    dataset = qc.load_by_id(dataid)
    para_list = dataset.parameters.split(",")
    voltage = dataset.get_parameter_data()[para_list[1]][para_list[1]]
    current = dataset.get_parameter_data()[para_list[1]][para_list[0]]
    fit_values = np.polyfit(current,voltage,1)
    return fit_values[0]


def get_R_from_IV_K2(dataid):
    dataset = qc.load_by_id(dataid)
    voltage = dataset.get_parameter_data()['meas_voltage_K2']['meas_voltage_K2']
    current = dataset.get_parameter_data()['meas_voltage_K2']['appl_current']
    fit_values = np.polyfit(current,voltage,1)
    return fit_values[0]

def autosave_plot_by_id(run_id, save_path):
    fig, ax = plt.subplots()
    plot_by_id(run_id, axes=ax)
    plt.savefig(save_path)
    plt.close()

def get_detaset_info(dataset=dataset):
    run_id = dataset.captured_run_id
    exp_name = dataset.exp_name
    sample_name = dataset.sample_name
    name = dataset.name
    description = dataset.description
    sample_junction = extract_sample_junction(sample_name)
    return run_id, exp_name, sample_name, sample_junction, name, description

def extract_sample_junction(sample_name):
    """Extracts the complete sample junction from the provided sample name.

    Args:
      sample_name: The name of the sample containing the junction information.

    Returns:
      The extracted sample junction, or None if not found.
    """

    delimiter = "_J"
    if delimiter in sample_name:
        # +3 to include "_J"
        return sample_name[:sample_name.find(delimiter) + 3]
    else:
        return None

def IV(run_id=1):
    dataset = qc.load_by_id(run_id)
    R = get_R_from_IV(run_id)
    run_id, exp_name, sample_name, sample_junction, name, description = get_detaset_info(
        dataset)
    df = dataset.to_pandas_dataframe().reset_index()
    para_list = dataset.parameters.split(",")

    # Create a Plotly trace
    trace = go.Scatter(x=df[para_list[0]], y=df[para_list[1]]*1e3, mode='lines', name='Voltage vs. Current')

    # Create layout with micro-scale y-axis
    layout = go.Layout(title=f'<b>#{run_id} {exp_name}</b> {sample_name}, R_fit={R:.4f} Ω', title_font=dict(size=28),
                       xaxis=dict(title=para_list[0], tickfont=dict(size=16),title_font=dict(size=20)),
                       yaxis=dict(title=f"{para_list[1]} mV", tickfont=dict(size=16),title_font=dict(size=20)), 
                       width=1080, height=960,
                       margin=dict(l=10, r=10, t=50, b=10))

    # Create the figure
    fig = go.Figure(data=[trace], layout=layout)
    
    fig.show()

def IV_diff(run_id=1):
    import numpy as np
    import plotly.graph_objs as go
    from scipy.signal import find_peaks
    dataset = qc.load_by_id(run_id)

    df = dataset.to_pandas_dataframe().reset_index()
    para_list = dataset.parameters.split(",")

    current = df[para_list[0]].tolist()
    voltage = df[para_list[1]].tolist()

    # Compute differential of voltage with respect to current
    differential_voltage = np.diff(voltage) / np.diff(current)

    # Since the differential will have one less data point, adjust the current data
    # to have the same length as the differential data
    current = current[:-1]

    # Find peaks in the differential signal
    peaks, _ = find_peaks(differential_voltage)

    # Extract peak current and peak differential voltage values
    peak_current = [current[i] for i in peaks]
    peak_voltage_diff = [differential_voltage[i] for i in peaks]

    # Sort the peaks based on their values
    sorted_peak_indices = np.argsort(peak_voltage_diff)[::-1]  # Sort in descending order
    top_two_peak_indices = sorted_peak_indices[:2]  # Select the top two indices

    # Extract the top two peaks
    top_two_peak_current = [peak_current[i] for i in top_two_peak_indices]
    top_two_peak_voltage_diff = [peak_voltage_diff[i] for i in top_two_peak_indices]

    # Calculate the center points of the top two peaks
    center_points = [(top_two_peak_current[i] + top_two_peak_current[i+1]) / 2 for i in range(len(top_two_peak_current) - 1)]

    # Calculate the difference between the top two biggest peaks
    peak_difference = abs(top_two_peak_current[0] - top_two_peak_current[1])

    # Determine the appropriate unit for current
    if peak_difference >= 1e-3:
        unit = "mA"
        conversion_factor = 1e3
    elif peak_difference >= 1e-6:
        unit = "μA"
        conversion_factor = 1e6
    else:
        unit = "nA"
        conversion_factor = 1e9

    # Determine the appropriate unit for current
    if peak_difference >= 1e-3:
        unit = "mA"
    elif peak_difference >= 1e-6:
        unit = "μA"
    elif peak_difference >= 1e-9:
        unit = "nA"
    else:
        unit = "pA"

    # Create a Plotly trace for the differential
    trace_diff = go.Scatter(x=[c * conversion_factor for c in current], y=differential_voltage, mode='lines', name='d(Voltage)/d(Current)')
    # Add markers for the top two peaks
    trace_top_two_peaks = go.Scatter(x=[p * conversion_factor for p in top_two_peak_current], y=top_two_peak_voltage_diff, mode='markers', marker=dict(color='red'), name='Top Two Peaks')
    # Add markers for the center points
    trace_center_points = go.Scatter(x=center_points, y=[0]*len(center_points), mode='markers', marker=dict(color='blue', symbol='cross'), name='Center Points')

    # Create layout
    layout = go.Layout(title=f'Run #{id} I vs. dV/dI',
                    xaxis=dict(title=f'Current ({unit})'),
                    yaxis=dict(title='d(Voltage)/d(Current)'),
                    legend=dict(orientation="h", yanchor="top", y=1.10, xanchor="center", x=0.5),
                    width=600, height=600  
                    )

    # Create the figure
    fig = go.Figure(data=[trace_diff, trace_top_two_peaks, trace_center_points], layout=layout)

    # Add annotation for the current value of center points
    for i, center_point in enumerate(center_points):
        fig.add_annotation(
            x=center_point * conversion_factor,
            y=0, #0.4 * max(differential_voltage),
            text=f'Center Point: {center_point * conversion_factor:.3f}{unit} <br> Peak difference: {peak_difference*conversion_factor:.3f} {unit}',
            showarrow=True,
            arrowhead=2,
            arrowsize=1,
            arrowwidth=2,
            arrowcolor='black',
            ax=-100,
            ay=-200 - 30 * i
        )

    # Plot the figure
    fig.show()

def get_Mag(show=True):
    Mag_x = magnet_x.field()
    Mag_y = magnet_y.field()
    Mag_z = magnet_z.field()
    if show:
        print(f"Mag_x: {Mag_x*1e3:.6f} mT")
        print(f"Mag_y: {Mag_y*1e3:.6f} mT")
        print(f"Mag_z: {Mag_z*1e3:.6f} mT")
    else: 
        return Mag_x, Mag_y, Mag_z
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 39
#      36     plt.savefig(save_path)
#      37     plt.close()
# ---> 39 def get_detaset_info(dataset=dataset):
#      40     run_id = dataset.captured_run_id
#      41     exp_name = dataset.exp_name
#
# NameError: name 'dataset' is not defined

# %%
get_Mag()
# Out:
# Mag_x: -0.000315 mT
# Mag_y: 0.099897 mT
# Mag_z: 0.003936 mT

# %%
df = dataset.to_pandas_dataframe().reset_index()
df
# Out:
#      appl_current  meas_voltage_K1
# 0   -1.000000e-06        -0.001004
# 1   -9.800000e-07        -0.000984
# 2   -9.600000e-07        -0.000964
# 3   -9.400000e-07        -0.000944
# 4   -9.200000e-07        -0.000924
# ..            ...              ...
# 96   9.200000e-07         0.000934
# 97   9.400000e-07         0.000954
# 98   9.600000e-07         0.000974
# 99   9.800000e-07         0.000995
# 100  1.000000e-06         0.001015
#
# [101 rows x 2 columns]

# %% [markdown]
# # Simple IVs

# %% [markdown]
# ## IV

# %%
keithley_24.output(1)
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
keithley_2.averaging_enabled(False)
keithley_24.output(0)

# %%
# Set current to 0
keithley_24.output(0)
appl_current(0e-6)

# %%
IV(3)

# %%
keithley_24.output(1)
I_range=0.1e-6
appl_current(-I_range) #Limit:1e-5 Amp(1MOhms risistor),1e-6 Amp(10MOhms risistor)
sleep(2)
# station.snapshot(update=True);
exp = qc.new_experiment('I-V', sample_name='104-06_J3_15-14-28-28_1M')
dataid = do1d(appl_current, -I_range ,I_range, 101, 0.01, meas_voltage_K1)
appl_current(0)
keithley_24.output(0)


plot_by_id(dataid)
save_path = r"C:\qcodes\personal_scripts\Albert\104\Plot\104_{}.png".format(dataid)  # Path to save the plot image
autosave_plot_by_id(dataid, save_path)
print(f"R = {get_R_from_IV(dataid)}")
# dataset = qc.load_by_id(dataid)
# IV(dataid)
# IV_diff(dataid)
# Out:
# Starting experimental run with id: 45.
# 100%|██████████| 101/101 [00:03<00:00, 29.65it/s]
# Trying to mark a run completed that was already completed.
# Trying to mark a run completed that was already completed.
# R = 858639.9428625512

# %%
for i in tqdm(range(1000)):
    keithley_24.output(1)
    I_range=1e-6
    appl_current(-I_range) #Limit:1e-5 Amp(1MOhms risistor),1e-6 Amp(10MOhms risistor)
    sleep(0.001)
    # station.snapshot(update=True);
    exp = qc.new_experiment('I-V', sample_name=f'103-03_J1_33-32-30-31_1M_F{i+1}')
    dataid = do1d(appl_current, -I_range ,I_range, 101, 0.0001, meas_voltage_K2)
    exp = qc.new_experiment('I-V', sample_name=f'103-03_J1_33-32-30-31_1M_B{i+1}')
    dataid = do1d(appl_current, I_range ,-I_range, 101, 0.0001, meas_voltage_K2)
    keithley_24.output(0)
    clear_output(True)

# %%
get_Mag()
# Out:
# Mag_x: -0.000145 mT
# Mag_y: -2.000120 mT
# Mag_z: 0.000656 mT

# %%
SGS.off()

# %%
SGS.power(0)

# %%
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)

# %%
for i in tqdm(range(21)):
    I_range = round(round(0.55 + 5*i * 1e-4, 6)* 1e-6, 10)  # Round to 3 decimal places
    print(I_range)
# Out:
# 100%|██████████| 21/21 [00:00<?, ?it/s]
# 5.5e-07
# 5.505e-07
# 5.51e-07
# 5.515e-07
# 5.52e-07
# 5.525e-07
# 5.53e-07
# 5.535e-07
# 5.54e-07
# 5.545e-07
# 5.55e-07
# 5.555e-07
# 5.56e-07
# 5.565e-07
# 5.57e-07
# 5.575e-07
# 5.58e-07
# 5.585e-07
# 5.59e-07
# 5.595e-07
# 5.6e-07

# %%
for i in tqdm(range(21)):
    keithley_24.output(1)
    I_range = round(round(0.55 + 5*i * 1e-4, 6)* 1e-6, 10) 
    appl_current(-I_range) #Limit:1e-5 Amp(1MOhms risistor),1e-6 Amp(10MOhms risistor)
    sleep(2)
    # station.snapshot(update=True);
    exp = qc.new_experiment('I-V', sample_name=f'103-04_J1_24-25-05-04(06-07G)_1M_By@0mT_{-I_range}_201')
    dataid = do1d(appl_current, -I_range ,I_range, 201, 0.00001, meas_voltage_K2)

    appl_current(0)
    keithley_24.output(0)


    plot_by_id(dataid)
    save_path = r"D:\data\Albert\103\Plot\104_{}.png".format(dataid)  # Path to save the plot image
    autosave_plot_by_id(dataid, save_path)
    print(f"ID:{dataid}")
    print(f"R = {get_R_from_IV_2(dataid)}")
    dataset = qc.load_by_id(dataid)
    IV(id=dataid)
    IV_diff(id=dataid)

# %%
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)

# %%
keithley_24.output(1)
I_range = -6e-6
appl_current(-I_range) #Limit:1e-5 Amp(1MOhms risistor),1e-6 Amp(10MOhms risistor)
sleep(2)
# station.snapshot(update=True);
exp = qc.new_experiment('I-V', sample_name=f'103-03_J2_27-26-30-31M(32G-33G-28G-29G)_1M_By@0.1mT{-I_range}')
dataid = do1d(appl_current, -I_range  ,I_range , 2601, 0.00001, meas_voltage_K2)
appl_current(0)
keithley_24.output(0)
plot_by_id(dataid)
save_path = r"D:\data\Albert\103\Plot\104_{}.png".format(dataid)  # Path to save the plot image
autosave_plot_by_id(dataid, save_path)
print(f"R = {get_R_from_IV_2(dataid)}")
dataset = qc.load_by_id(dataid)
# Out:
# Starting experimental run with id: 6525.
# 100%|██████████| 2601/2601 [04:31<00:00,  9.57it/s]
# Trying to mark a run completed that was already completed.
# Trying to mark a run completed that was already completed.
# ID:6525
# R = 54.84617344356483

# %%
keithley_24.output(1)
I_range = 6e-6
appl_current(-I_range) #Limit:1e-5 Amp(1MOhms risistor),1e-6 Amp(10MOhms risistor)
sleep(2)
# station.snapshot(update=True);
exp = qc.new_experiment('I-V', sample_name=f'103-03_J2_27-26-30-31M(32G-33G-28G-29G)_1M_By@0.1mT{-I_range}')
dataid = do1d(appl_current, -I_range  ,I_range , 2601, 0.00001, meas_voltage_K2)
appl_current(0)
keithley_24.output(0)
plot_by_id(dataid)
save_path = r"D:\data\Albert\103\Plot\104_{}.png".format(dataid)  # Path to save the plot image
autosave_plot_by_id(dataid, save_path)
print(f"ID:{dataid}")
print(f"R = {get_R_from_IV_2(dataid)}")
dataset = qc.load_by_id(dataid)
# IV(id=dataid)
# IV_diff(id=dataid)
# Out:
# Starting experimental run with id: 6524.
# 100%|██████████| 2601/2601 [04:34<00:00,  9.46it/s]
# Trying to mark a run completed that was already completed.
# Trying to mark a run completed that was already completed.
# ID:6524
# R = 54.721016451832675

# %%
25-05-06-07(04-24G)

# %%
keithley_24.output(1)
I_range=-7e-6
appl_current(-I_range) #Limit:1e-5 Amp(1MOhms risistor),1e-6 Amp(10MOhms risistor)
sleep(2)
# station.snapshot(update=True);
exp = qc.new_experiment('I-V', sample_name='103-03_J2_32-30-26-27_1M_By@0mT')
dataid = do1d(appl_current, -I_range ,I_range, 1401, 0.0001, meas_voltage_K2)

appl_current(0)
keithley_24.output(0)


plot_by_id(dataid)
save_path = r"D:\data\Albert\103\Plot\104_{}.png".format(dataid)  # Path to save the plot image
autosave_plot_by_id(dataid, save_path)
print(f"ID:{dataid}")
print(f"R = {get_R_from_IV_2(dataid)}")
dataset = qc.load_by_id(dataid)
IV(id=dataid)
IV_diff(id=dataid)
# Out:
# There is (are) already experiment(s) with the name of I-V and sample name of 103-03_J2_32-30-26-27_1M_By@0mT in the database.
# Starting experimental run with id: 6173.
# 100%|██████████| 1401/1401 [02:26<00:00,  9.58it/s]
# Trying to mark a run completed that was already completed.
# Trying to mark a run completed that was already completed.
# ID:6173
# R = 63.030417570774055

# %%
keithley_24.output(1)
I_range=7e-6
appl_current(-I_range) #Limit:1e-5 Amp(1MOhms risistor),1e-6 Amp(10MOhms risistor)
sleep(2)
# station.snapshot(update=True);
exp = qc.new_experiment('I-V', sample_name='103-03_J2_32-30-26-27_1M_By@0mT')
dataid = do1d(appl_current, -I_range ,I_range, 1401, 0.0001, meas_voltage_K2)

appl_current(0)
keithley_24.output(0)


plot_by_id(dataid)
save_path = r"D:\data\Albert\103\Plot\104_{}.png".format(dataid)  # Path to save the plot image
autosave_plot_by_id(dataid, save_path)
print(f"ID:{dataid}")
print(f"R = {get_R_from_IV_2(dataid)}")
dataset = qc.load_by_id(dataid)
IV(id=dataid)
IV_diff(id=dataid)
# Out:
# There is (are) already experiment(s) with the name of I-V and sample name of 103-03_J2_32-30-26-27_1M_By@0mT in the database.
# Starting experimental run with id: 6172.
# 100%|██████████| 1401/1401 [02:26<00:00,  9.59it/s]
# Trying to mark a run completed that was already completed.
# Trying to mark a run completed that was already completed.
# ID:6172
# R = 63.07049938088664

# %%
# Set current to 0
keithley_24.output(0)
appl_current(0e-6)

# %%
keithley_24.output(1)
appl_current(0.1e-7)

# %%
runid=6
print(get_R_from_IV_2(runid))

# %% [markdown]
# ## 加TG (1D)

# %%
keithley_19.output(1)
appl_TG(0)

# %%
keithley_19.output(1)
keithley_24.output(1)
appl_TG(-50)
sleep(3)
appl_current(-1.5e-8)
sleep(1)

# station.snapshot(update=True);
exp = qc.new_experiment('IV', sample_name='TG21')

#do1d(param_set, start, stop, num_points, delay, *param_meas)
dataid = do1d(appl_current, -1.5e-8 ,1.5e-8, 101, 0.05, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

keithley_19.output(0)
keithley_24.output(0)
appl_current(0)
plot_by_id(dataid)
#print(get_R_from_IV(dataid))
# print(get_R_from_IV_2(dataid))

# %% [markdown]
# ## 歸零

# %%
#keithley_19.output(1)
keithley_24.output(1)

appl_current(0)
sleep(1)
#appl_TG(0)
sleep(5)

#keithley_19.output(0)
keithley_24.output(0)

# %% [markdown]
# # Magnetic field

# %% [markdown]
# ## IV vs Bx

# %%
keithley_24.rangev()

# %%
keithley_24.volt(0)
keithley_24.output(1) #output off
sleep(1)
appl_current(1.5e-7)
sleep(2)
meas_voltage_K2()

# %%
sleep(120)

# %%
def get_Mag(show=True):
    Mag_x = magnet_x.field()
    Mag_y = magnet_y.field()
    Mag_z = magnet_z.field()
    if show:
        print(f"Mag_x: {Mag_x*1e3:.6f} mT")
        print(f"Mag_y: {Mag_y*1e3:.6f} mT")
        print(f"Mag_z: {Mag_z*1e3:.6f} mT")
    else: 
        return Mag_x, Mag_y, Mag_z
get_Mag()
# Out:
# Mag_x: 0.000557 mT
# Mag_y: 15.200061 mT
# Mag_z: 0.001476 mT

# %%
get_Mag()
# Out:
# Mag_x: 0.000048 mT
# Mag_y: 0.100164 mT
# Mag_z: -0.000984 mT

# %%
magnet_y.field()
# Out:
# -4.61e-07

# %%
for i in tqdm(range(23), desc="First loop"):
    value = (25 - i) * 1e-3 
    value = float(f"{value:.10f}")
    print(value)

# %%
from tqdm import tqdm
import time

from IPython.display import clear_output
# First loop
for i in tqdm(range(6), desc="First loop"):
    Mag_x = magnet_x.field()
    value = (15 + i) * 1e-3
    value = float(f"{value:.10f}")
    magnet_x.field(value)
    print(f"magnet_x is {Mag_x:.8f} T")
    time.sleep(15)
    clear_output(True)

# Pause for 30 seconds
time.sleep(60)

# Second loop
for i in tqdm(range(23), desc="First loop"):
    Mag_x = magnet_x.field()
    value = (25 - i) * 1e-3 
    value = float(f"{value:.10f}")
    magnet_x.field(value)
    print(f"magnet_x is {Mag_x:.8f} T")
    time.sleep(15)
    clear_output(True)

# Pause for 180 seconds
time.sleep(300)

# %%
magnet_x.field(-20)

# %%
Mag = -20e-3
I_range=2.5e-6
keithley_24.output(1)
sleep(2)
magnet_x.field(Mag)
sleep(10)
appl_current(-I_range)
sleep(3)
direction = 'backward' if Mag > 0 else 'forward'


# station.snapshot(update=True);
exp = qc.new_experiment('IV vs Bx', sample_name=f'103-06_J2_12-13-18-19_1M_Bx_{direction}_By@0mT')

dataid = do2d(magnet_x.field, Mag, -Mag, 76 , 0.7, appl_current, -I_range ,I_range, 101, 0.01, meas_voltage_K2)

appl_current(0)
keithley_24.output(0)
# magnet_y.field(0)

plot_by_id(dataid)
autosave_plot_by_id(dataid, save_path)

# %%
keithley_24.output(1)
sleep(2)
Mag = 10e-3
I_range=2.5e-5

magnet_x.field(Mag)
sleep(30)
appl_current(-I_range)
sleep(3)
direction = 'backward' if Mag > 0 else 'forward'


# station.snapshot(update=True);

exp = qc.new_experiment('IV vs Bx', sample_name=f'094-20IV_Bx_16-17-19-18_10M_{direction}')

dataid = do2d(magnet_x.field, Mag, -Mag, 101 , 1.5, appl_current, -I_range ,I_range, 101, 0.05, meas_voltage_K2)#M:I Delay time 10:1


appl_current(0)
keithley_24.output(0)
# magnet_x.field(0)

plot_by_id(dataid)
autosave_plot_by_id(dataid, save_path)

# %%
set_magnetic_field_stepwise(magnet=magnet_x, current_field=-40e-3, target_field=-18e-3, step_size=1e-3, delay=2.5)

# %%
def set_magnetic_field_stepwise(magnet=magnet_x, current_field=0, target_field=-10e-3, step_size=1e-3, delay=2.5):
    
    """Set the magnetic field with anti-hysteresis mechanism witch will go to target magnetic field +/- 5mT, 
    if the target magnetic field is greater/less than the current magnetic field, 
    then slowly ramp back the magnetic field to the target magnetic field

    Args:
        magnet (_type_, optional): magnet_x,magnet_y,magnet_z. Defaults to magnet_x.
        current_field (int, optional): _description_. Defaults to 0 T.
        target_field (_type_, optional): _description_. Defaults to -10e-3 T.
        step_size (_type_, optional): _description_. Defaults to 1e-3 T.
        delay (float, optional): _description_. Defaults to 2 sec.
    
    """
    
    from tqdm.notebook import tqdm
    import math
    # Calculate total steps for tqdm progress bar
    total_steps = math.ceil(abs((target_field - current_field) / step_size)) * 2
    progress_bar = tqdm(total=total_steps)

    # Determine the intermediate target field
    intermediate_target_field = target_field + 5e-3 if target_field > current_field else target_field - 5e-3
    # Slowly ramp the magnetic field to the intermediate target field
    while abs(intermediate_target_field - current_field) > step_size:
        if intermediate_target_field > current_field:
            current_field += step_size
            magnet.field(current_field)
        else:
            current_field -= step_size
            magnet.field(current_field)
        time.sleep(delay)
        progress_bar.update(1)  # Update progress bar
    # Slowly ramp back the magnetic field to the target_field
    while abs(target_field - current_field) > step_size:
        if target_field > current_field:
            current_field += step_size
            magnet.field(current_field)
        else:
            current_field -= step_size
            magnet.field(current_field)
        time.sleep(delay)
        progress_bar.update(1)  # Update progress bar
    magnet.field(target_field)
    progress_bar.n = total_steps  # Set progress bar to 100%
    progress_bar.refresh()  # Refresh the progress bar to show the update
    progress_bar.close()  # Close progress bar when done

# %%
for i in range(6):
    magnet_x.field((-10-i)*1e-3)
    sleep(4)
sleep(10)

for i in range(16):
    magnet_x.field((15+i)*1e-3)
    sleep(4)
sleep(10)

# %%
for i in range(25):
    print(-24+i)

# %%
magnet_x.field(-19e-3)
sleep(10)
#magnet_x.field(e-3)
#sleep(10)
#magnet_x.field(12.8e-3)
#sleep(10)

# %% [markdown]
# ## IV vs By

# %%
get_Mag()
# Out:
# Mag_x: -0.000194 mT
# Mag_y: -0.000340 mT
# Mag_z: 0.002624 mT

# %%
magnet_y.field(0e-3)

# %%
for i in tqdm(range(21), desc="2nd loop"):
    
    value = (-10 + i*0.5) * 1e-3 
    value = float(f"{value:.10f}")
    magnet_y.field(value)
    get_Mag()
    time.sleep(15)
    clear_output(True)
# Out:
# 2nd loop: 100%|██████████| 21/21 [06:16<00:00, 17.95s/it]

# %%
# First loop
for i in tqdm(range(11), desc="First loop"):
    
    value = (5 +i) * 1e-3
    value = float(f"{value:.10f}")
    magnet_y.field(value)
    get_Mag()
    time.sleep(15)
    clear_output(True)

# Pause for 30 seconds
time.sleep(60)

# Second loop
for i in tqdm(range(11), desc="2nd loop"):
    
    value = (-10 + i) * 1e-3 
    value = float(f"{value:.10f}")
    magnet_y.field(value)
    get_Mag()
    time.sleep(15)
    clear_output(True)
# Pause for 180 seconds
time.sleep(300)
# Out:
# 2nd loop: 100%|██████████| 6/6 [01:55<00:00, 19.26s/it]

# %%
magnet_y.field()
# Out:
# -0.00500115

# %%
Mag =5e-3
I_range=0.6e-6
keithley_24.output(1)
sleep(2)
magnet_y.field(Mag)
sleep(10)
appl_current(-I_range)
sleep(3)
direction = 'backward' if Mag > 0 else 'forward'


# station.snapshot(update=True);
exp = qc.new_experiment('IV vs By', sample_name=f'103-03_J2_27-26-30-31M(32G-33G-28G-29G)_1M_By_{direction}_{-I_range}')

dataid = do2d(magnet_y.field, Mag, -Mag, 201 , 0.5, appl_current, -I_range ,I_range,  201, 0.0001, meas_voltage_K2)

appl_current(0)
keithley_24.output(0)
# magnet_y.field(0)

plot_by_id(dataid)
autosave_plot_by_id(dataid, save_path)
# Out:
# Starting experimental run with id: 6501.
# first parameter: 100%|██████████| 201/201 [20:06<00:00,  6.00s/it]
# Trying to mark a run completed that was already completed.
# Trying to mark a run completed that was already completed.

# %%
Mag =-5e-3
I_range=5e-6
keithley_24.output(1)
sleep(2)
magnet_y.field(Mag)
sleep(10)
appl_current(-I_range)
sleep(3)
direction = 'backward' if Mag > 0 else 'forward'


# station.snapshot(update=True);
exp = qc.new_experiment('IV vs By', sample_name=f'103-03_J2_27-26-30-31M(32G-33G-28G-29G)_1M_By_{direction}_{-I_range}')

dataid = do2d(magnet_y.field, Mag, -Mag, 201 , 0.5, appl_current, -I_range ,I_range,  201, 0.0001, meas_voltage_K2)

appl_current(0)
keithley_24.output(0)
# magnet_y.field(0)

plot_by_id(dataid)
autosave_plot_by_id(dataid, save_path)
# Out:
# Starting experimental run with id: 6500.
# first parameter: 100%|██████████| 201/201 [22:46<00:00,  6.80s/it]
# Trying to mark a run completed that was already completed.
# Trying to mark a run completed that was already completed.

# %%
32-

# %%
# First loop
for i in tqdm(range(6), desc="First loop"):
    Mag_x = magnet_y.field()
    value = (1.5 +i) * 1e-3
    value = float(f"{value:.10f}")
    magnet_y.field(value)
    print(f"magnet_y is {Mag_x:.8f} T")
    time.sleep(15)
    clear_output(True)

# Pause for 30 seconds
time.sleep(60)

# Second loop
for i in tqdm(range(6), desc="2nd loop"):
    Mag_x = magnet_y.field()
    value = (6.5 - i) * 1e-3 
    value = float(f"{value:.10f}")
    magnet_y.field(value)
    print(f"magnet_y is {Mag_x:.8f} T")
    time.sleep(15)
    clear_output(True)

# Pause for 180 seconds
time.sleep(300)

# %%
Mag = 1.5e-3
I_range=2.5e-6
keithley_24.output(1)
sleep(2)
magnet_y.field(Mag)
sleep(10)
appl_current(-I_range)
sleep(3)
direction = 'backward' if Mag > 0 else 'forward'


# station.snapshot(update=True);
exp = qc.new_experiment('IV vs By', sample_name=f'103-06_J2_12-13-18-19_1M_By_{direction}_Bx@3mT')

dataid = do2d(magnet_y.field, Mag, -Mag, 1001 , 0.4, appl_current, -I_range ,I_range, 151, 0.01, meas_voltage_K2)

appl_current(0)
keithley_24.output(0)
# magnet_y.field(0)

plot_by_id(dataid)
autosave_plot_by_id(dataid, save_path)

# %%
Mag()

# %%
Mag = 1.5e-3
I_range=1e-6
keithley_24.output(1)
sleep(2)
magnet_y.field(Mag)
sleep(10)
appl_current(-I_range)
sleep(3)
direction = 'backward' if Mag > 0 else 'forward'


# station.snapshot(update=True);
exp = qc.new_experiment('IV vs By', sample_name=f'103-01_J1_21-20-23-22_1M_By_{direction}_Bx@0mT')

dataid = do2d(magnet_y.field, Mag, -Mag, 151 , 0.9, appl_current, -I_range ,I_range, 201, 0.01, meas_voltage_K2)

appl_current(0)
keithley_24.output(0)
# magnet_y.field(0)

plot_by_id(dataid)
autosave_plot_by_id(dataid, save_path)

# %%
from tqdm import tqdm
import time

# First loop
for i in tqdm(range(6), desc="First loop"):
    value = (1.5 + i) * 1e-3 
    magnet_y.field(value)
    print(f"magnet_y is {value:.8f} T")
    time.sleep(10)

# Pause for 30 seconds
time.sleep(30)

# Second loop
for i in tqdm(range(8), desc="First loop"):
    value = (7 - i) * 1e-3 
    magnet_y.field(value)
    print(f"magnet_y is {value:.8f} T")
    time.sleep(10)

# Pause for 180 seconds
time.sleep(300)

# %%
def combined_loop(start=0, end=5 ):
  for i in tqdm(range((end-start)+6), desc="First loop"):
    value = start + i
    print(f"{value* 1e-3:.5f}")

  for i in tqdm(range(6), desc="Second loop"):
    value = end+5 - i
    print(f"{value* 1e-3:.5f}")

combined_loop()

# %%
Mag = 3e-3
I_range=1e-6
keithley_24.output(1)
sleep(2)
magnet_y.field(Mag)
sleep(10)
appl_current(-I_range)
sleep(3)
direction = 'backward' if Mag > 0 else 'forward'


# station.snapshot(update=True);
exp = qc.new_experiment('IV vs By', sample_name=f'103-04_J2_04-05-06-07_1M_By_{direction}_Bx@0mT')

dataid = do2d(magnet_y.field, Mag, -Mag, 101 , 1.5, appl_current, -I_range ,I_range, 101, 0.01, meas_voltage_K2)

appl_current(0)
keithley_24.output(0)
# magnet_y.field(0)

plot_by_id(dataid)
autosave_plot_by_id(dataid, save_path)

# %%
from tqdm import tqdm
import time

# First loop
for i in tqdm(range(6), desc="First loop"):
    magnet_y.field((-3 - i) * 1e-3)
    time.sleep(15)

# Pause for 30 seconds
time.sleep(30)

# Second loop
for i in tqdm(range(7), desc="Second loop"):
    magnet_y.field((-8 + i) * 1e-3)
    time.sleep(15)

# Pause for 180 seconds
time.sleep(300)

# %%
magnet_y.field(-1.5e-3)
print("By at -1.5 mT")

# %%
Mag = -3e-3
I_range=1e-6
keithley_24.output(1)
sleep(2)
magnet_y.field(Mag)
sleep(10)
appl_current(-I_range)
sleep(3)
direction = 'backward' if Mag > 0 else 'forward'


# station.snapshot(update=True);
exp = qc.new_experiment('IV vs By', sample_name=f'103-04_J2_04-05-06-07_1M_By_{direction}_Bx@0mT')

dataid = do2d(magnet_y.field, Mag, -Mag, 501 , 1, appl_current, -I_range ,I_range, 251, 0.01, meas_voltage_K2)

appl_current(0)
keithley_24.output(0)
# magnet_y.field(0)

plot_by_id(dataid)
autosave_plot_by_id(dataid, save_path)

# %%
from tqdm import tqdm
import time

# First loop
for i in tqdm(range(6), desc="First loop"):
    magnet_y.field((3 + i) * 1e-3)
    time.sleep(10)

# Pause for 30 seconds
time.sleep(30)

# Second loop
for i in tqdm(range(6), desc="Second loop"):
    magnet_y.field((8 - i) * 1e-3)
    time.sleep(10)

# Pause for 180 seconds
time.sleep(300)

# %%
Mag = 3e-3
I_range=1e-6
keithley_24.output(1)
sleep(2)
magnet_y.field(Mag)
sleep(10)
appl_current(-I_range)
sleep(3)
direction = 'backward' if Mag > 0 else 'forward'


# station.snapshot(update=True);
exp = qc.new_experiment('IV vs By', sample_name=f'103-04_J2_04-05-06-07_1M_By_{direction}_Bx@0mT')

dataid = do2d(magnet_y.field, Mag, -Mag, 501 , 1, appl_current, -I_range ,I_range, 251, 0.01, meas_voltage_K2)

appl_current(0)
keithley_24.output(0)
# magnet_y.field(0)

plot_by_id(dataid)
autosave_plot_by_id(dataid, save_path)

# %%
magnet_y.field(5e-3)

# %%
for i in range(9):
    magnet_y.field((0+i)*1e-3)
    sleep(4)
sleep(10)

for i in range(6):
    magnet_y.field((8-i)*1e-3)
    sleep(4)

sleep(60)
# magnet_y.field(21.5e-3)
sleep(60)
#magnet_y.field(0.48e-3)
#sleep(5)

# %%
for i in range(4):
    print(8-i)

# %%
keithley_24.output(1)
sleep(2)
Mag = -40e-3
I_range=2e-8

magnet_y.field(Mag)
sleep(10)
appl_current(-I_range)
sleep(3)
direction = 'backward' if Mag > 0 else 'forward'


# station.snapshot(update=True);

exp = qc.new_experiment('IV vs By', sample_name=f'094-20IV_By_16-17-19-18_10M_{direction}_Bx@-18.5mT')

dataid = do2d(magnet_y.field, Mag, -Mag, 601 , 2, appl_current, -I_range ,I_range, 201, 0.1, meas_voltage_K2)


appl_current(0)
keithley_24.output(0)
# magnet_y.field(0)

plot_by_id(dataid)
autosave_plot_by_id(dataid, save_path)

# %%
for i in range(24):
    print(45-i)

# %% [markdown]
# ## IV vs Bz

# %%
keithley_24.output(1)
sleep(2)
magnet_z.field(-80e-3)
sleep(60)
appl_current(-2e-7)
sleep(5)

# station.snapshot(update=True);

exp = qc.new_experiment('IV vs Bz', sample_name='IV_Bz_33_32_30_31_10M_forward')

dataid = do2d(magnet_z.field,-80e-3,80e-3, 71 , 20, appl_current, -2e-7 ,2e-7, 101, 0.05, meas_voltage_K2)

appl_current(0)

keithley_24.output(0)
# magnet_y.field(0)

plot_by_id(dataid)

# %%
#magnet_z.field(20e-3)
#sleep(5)
magnet_z.field(-6.1e-3)
sleep(5)

# %% [markdown]
# ## IV w/ Bx

# %%
keithley_24.output(1)
sleep(2)
magnet_x.field(0.23e-3)
appl_current(-0.5e-6)
sleep(10)

# station.snapshot(update=True);
exp = qc.new_experiment('I vs V', sample_name='IV_w/_Bx')

#do1d(param_set, start, stop, num_points, delay, *param_meas)
dataid = do1d(appl_current, -0.5e-6 ,0.5e-6, 101, 0.05, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

appl_current(0)
plot_by_id(dataid)
# print(get_R_from_IV(dataid))
#print(get_R_from_IV_2(dataid))

keithley_24.output(0)

# %% [markdown]
# ## IV w/ By

# %%
keithley_24.output(1)
keithley_2.averaging_count(30)
#keithley_2.averaging_enabled(False)

sleep(2)
magnet_y.field(0e-3)
appl_current(-2e-7)
sleep(20)

# station.snapshot(update=True);
exp = qc.new_experiment('I vs V', sample_name='IV_w/_By@0mT_forward_Avg30')

#do1d(param_set, start, stop, num_points, delay, *param_meas)
dataid = do1d(appl_current, -2e-7 ,2e-7, 201, 0.05, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

appl_current(0)
plot_by_id(dataid)
# print(get_R_from_IV(dataid))
#print(get_R_from_IV_2(dataid))

keithley_24.output(0)

# %% [markdown]
# ## MR

# %%
keithley_24.output(1)
sleep(2)
magnet_y.field(-0.1)
sleep(5)
#keithley_19.output(1)
appl_current(1e-7)
sleep(5)

# station.snapshot(update=True);

exp = qc.new_experiment('I vs By_MR', sample_name='072_14IVf_25_24_29_29_By_+-0.1T_MR_for')

dataid = do1d(magnet_y.field, -0.1, 0.1, 71 , 1, meas_voltage_K2)

appl_current(0)
keithley_24.output(0)
#keithley_19.output(0)
magnet_y.field(0)

plot_by_id(dataid)

# %% [markdown]
# ## IV w/Bz

# %%
keithley_24.output(1)
keithley_2.averaging_count(10)
#keithley_2.averaging_enabled(False)

sleep(2)
magnet_z.field(0e-3)
appl_current(-2e-7)
sleep(30)

# station.snapshot(update=True);
exp = qc.new_experiment('I vs V', sample_name='IV_w/_f_Bz@0mT_forward_Avg10')

#do1d(param_set, start, stop, num_points, delay, *param_meas)
dataid = do1d(appl_current, -2e-7 ,2e-7, 201, 0.05, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

appl_current(0)
plot_by_id(dataid)
# print(get_R_from_IV(dataid))
#print(get_R_from_IV_2(dataid))

keithley_24.output(0)

# %% [markdown]
# # Zero everything

# %%
appl_current(0)
appl_TG(0)
magnet_y.field(0)
sleep(5)
magnet_x.field(0)
sleep(5)
magnet_z.field(0)
sleep(5)
#appl_voltage_AC(0.004)
#SGS.off()
keithley_24.output(0)

# %%
appl_current(0)

# %% [markdown]
# # Gate simple sweeps

# %% [markdown]
# ## 加TG (2D)

# %%
appl_current(0)
sleep(1)
appl_TG(0)
sleep(5)

# %%
magnet_x.field(-0.044e-3)
sleep(10)
magnet_y.field(-6.016e-3)
sleep(10)

# %%
keithley_19.output(1)
keithley_24.output(1)
appl_TG(-30)
sleep(5)
appl_current(-1.5e-8)
sleep(1)

exp = qc.new_experiment('I_vs_Vgate_up', sample_name='33_32_30_31_1M_TG21')
dataid = do2d(appl_TG, -30, 30, 301, 0.5, appl_current, -1.5e-8, 1.5e-8, 101, 0.1, meas_voltage_K2)

appl_TG(0)
sleep(5)
appl_current(0e-7)
sleep(5)

keithley_19.output(0)
keithley_24.output(0)

plot_by_id(dataid)

# %% [markdown]
# # RF

# %% [markdown]
# ## I vs RF_f

# %% [markdown]
# ### sensitive check

# %%
SGS.power()
SGS.frequency()

# %%
SGS.on()

# %%
SGS.off()

# %%
magnet_x.field(0.4e-3)
sleep(10)
magnet_y.field(2.53e-3)
sleep(10)

# %%
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(False)

# %% [markdown]
# ### I vs RF_f (1D)

# %%
SGS.off()
exp = qc.new_experiment('I-RF_f', sample_name='103-06_J2_12-13-14-15_1M_@0mT')
SGS.power(0)
SGS.frequency(0.1e9)
SGS.on()
sleep(1)
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(False)
keithley_24.output(1)

appl_current(0.4e-6)
#appl_TG(10)
# magnet_x.field(0.4e-3)
# magnet_y.field(2.53e-3)

dataid = do1d(SGS.frequency, 11.4e9, 12.2e9, 201, 0.1, meas_voltage_K2)
appl_current(0)
SGS.off()
keithley_24.output(0)
plot_by_id(dataid)
# Out:
# There is (are) already experiment(s) with the name of I-RF_f and sample name of 103-06_J2_12-13-14-15_1M_@0mT in the database.
# Starting experimental run with id: 6149.
# 100%|██████████| 201/201 [00:25<00:00,  7.97it/s]
# Trying to mark a run completed that was already completed.
# ([<AxesSubplot:title={'center':'Run #6149, Experiment I-RF_f (103-06_J2_12-13-14-15_1M_@0mT)'}, xlabel='Frequency (GHz)', ylabel='meas_voltage_K2 (μV)'>],
#  [None])

# %% [markdown]
# ### I vs RF_f (2D)

# %%
SGS.off()

# %%
SGS.off()
SGS.power(0)
SGS.frequency(0.1e9)
SGS.on()
keithley_2.averaging_count(1)
keithley_2.averaging_enabled(False)
keithley_24.output(1)

I_range = 8e-6
appl_current(-I_range)
#appl_TG(-10)
# magnet_x.field(0.4e-3)
# magnet_y.field(2.53e-3)
# sleep(1)

# station.snapshot(update=True);
exp = qc.new_experiment('IV-RF_f', sample_name=f'103-03_J2_27-26-30-31M(32G-33G-28G-29G)_1M_RF@0dBm_By@0.1mT')

#do1d(param_set, start, stop, num_points, delay, *param_meas)
dataid = do2d(SGS.frequency, 1e9, 20e9, 191, 0.0001, appl_current,-I_range ,I_range, 201, 0.0001, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()
keithley_24.output(0)
SGS.off()
appl_current(0)
plot_by_id(dataid)
save_path = r"D:\data\Albert\103\Plot\104_{}.png".format(dataid)  # Path to save the plot image
autosave_plot_by_id(dataid, save_path)
# Out:
# Starting experimental run with id: 6506.
# first parameter: 100%|██████████| 191/191 [14:43<00:00,  4.63s/it]
# Trying to mark a run completed that was already completed.
# Trying to mark a run completed that was already completed.

# %%
SGS.off()
SGS.power(20)
SGS.frequency(0.1e9)
SGS.on()
keithley_2.averaging_count(1)
keithley_2.averaging_enabled(False)
keithley_24.output(1)

I_range = 6e-6
appl_current(-I_range)
#appl_TG(-10)
# magnet_x.field(0.4e-3)
# magnet_y.field(2.53e-3)
# sleep(1)

# station.snapshot(update=True);
exp = qc.new_experiment('IV-RF_f', sample_name=f'103-03_J2_27-26-30-31M(32G-33G-28G-29G)_1M_RF@-10dBm_By@0.1mT')

#do1d(param_set, start, stop, num_points, delay, *param_meas)
dataid = do2d(SGS.frequency, 1e9, 20e9, 191, 0.0001, appl_current,-I_range ,I_range, 201, 0.0001, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()
keithley_24.output(0)
SGS.off()
appl_current(0)
plot_by_id(dataid)
save_path = r"D:\data\Albert\103\Plot\104_{}.png".format(dataid)  # Path to save the plot image
autosave_plot_by_id(dataid, save_path)
# Out:
# There is (are) already experiment(s) with the name of IV-RF_f and sample name of 103-03_J2_27-26-30-31M(32G-33G-28G-29G)_1M_RF@-10dBm_By@0.1mT in the database.
# Starting experimental run with id: 6509.
# first parameter: 100%|██████████| 191/191 [14:37<00:00,  4.60s/it]
# Trying to mark a run completed that was already completed.
# Trying to mark a run completed that was already completed.

# %%
SGS.off()
SGS.power(20)
SGS.frequency(5.9e9)
SGS.on()
keithley_2.averaging_count(1)
keithley_2.averaging_enabled(False)
keithley_24.output(1)

I_range = 6e-6
appl_current(-I_range)
#appl_TG(-10)
# magnet_x.field(0.4e-3)
# magnet_y.field(2.53e-3)
# sleep(1)

# station.snapshot(update=True);
exp = qc.new_experiment('IV-RF_f', sample_name=f'103-03_J2_27-26-30-31M(32G-33G-28G-29G)_1M_RF@20dBm_By@0.1mT')

#do1d(param_set, start, stop, num_points, delay, *param_meas)
dataid = do2d(SGS.frequency, 5.9e9, 6.0e9, 251, 0.0001, appl_current,-I_range ,I_range, 501, 0.0001, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()
keithley_24.output(0)
SGS.off()
appl_current(0)
plot_by_id(dataid)
save_path = r"D:\data\Albert\103\Plot\104_{}.png".format(dataid)  # Path to save the plot image
autosave_plot_by_id(dataid, save_path)
# Out:
# There is (are) already experiment(s) with the name of IV-RF_f and sample name of 103-03_J2_27-26-30-31M(32G-33G-28G-29G)_1M_RF@20dBm_By@0.1mT in the database.
# Starting experimental run with id: 6519.
# first parameter: 100%|██████████| 251/251 [49:35<00:00, 11.86s/it]
# Trying to mark a run completed that was already completed.
# Trying to mark a run completed that was already completed.

# %%
SGS.off()
SGS.power(20)
SGS.frequency(5.535e9)
SGS.on()
keithley_2.averaging_count(1)
keithley_2.averaging_enabled(False)
keithley_24.output(1)

I_range = 6e-6
appl_current(-I_range)
#appl_TG(-10)
# magnet_x.field(0.4e-3)
# magnet_y.field(2.53e-3)
# sleep(1)

# station.snapshot(update=True);
exp = qc.new_experiment('IV-RF_f', sample_name=f'103-03_J2_27-26-30-31M(32G-33G-28G-29G)_1M_RF@20dBm_By@0.1mT')

#do1d(param_set, start, stop, num_points, delay, *param_meas)
dataid = do2d(SGS.frequency, 5.535e9, 5.585e9, 251, 0.0001, appl_current,-I_range ,I_range, 501, 0.0001, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()
keithley_24.output(0)
SGS.off()
appl_current(0)
plot_by_id(dataid)
save_path = r"D:\data\Albert\103\Plot\104_{}.png".format(dataid)  # Path to save the plot image
autosave_plot_by_id(dataid, save_path)
# Out:
# There is (are) already experiment(s) with the name of IV-RF_f and sample name of 103-03_J2_27-26-30-31M(32G-33G-28G-29G)_1M_RF@20dBm_By@0.1mT in the database.
# Starting experimental run with id: 6518.
# first parameter: 100%|██████████| 251/251 [48:50<00:00, 11.68s/it]
# Trying to mark a run completed that was already completed.
# Trying to mark a run completed that was already completed.

# %%
SGS.off()
SGS.power(20)
SGS.frequency(0.1e9)
SGS.on()
keithley_2.averaging_count(1)
keithley_2.averaging_enabled(False)
keithley_24.output(1)

I_range = 6e-6
appl_current(-I_range)
SGS_power = SGS.power()
#appl_TG(-10)
# magnet_x.field(0.4e-3)
# magnet_y.field(2.53e-3)
# sleep(1)

# station.snapshot(update=True);
exp = qc.new_experiment('IV-RF_f', sample_name=f'103-03_J2_27-26-30-31M(32G-33G-28G-29G)_1M_RF@{SGS_power}dBm_By@0.1mT')

#do1d(param_set, start, stop, num_points, delay, *param_meas)
dataid = do2d(SGS.frequency, 3.9e9, 6.9e9, 301, 0.0001, appl_current,-I_range ,I_range, 251, 0.0001, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()
keithley_24.output(0)
SGS.off()
appl_current(0)
plot_by_id(dataid)
save_path = r"D:\data\Albert\103\Plot\104_{}.png".format(dataid)  # Path to save the plot image
autosave_plot_by_id(dataid, save_path)
# Out:
# There is (are) already experiment(s) with the name of IV-RF_f and sample name of 103-03_J2_27-26-30-31M(32G-33G-28G-29G)_1M_RF@20.0dBm_By@0.1mT in the database.
# Starting experimental run with id: 6513.
# first parameter: 100%|██████████| 301/301 [29:46<00:00,  5.94s/it]
# Trying to mark a run completed that was already completed.
# Trying to mark a run completed that was already completed.

# %%
appl_current(0)
#appl_TG(0)
magnet_y.field(0)
sleep(2)
magnet_x.field(0)
sleep(2)
#appl_voltage_AC(0.004)
SGS.off()

# %% [markdown]
# ## IV vs RF_f

# %% [markdown]
# ### Shapiro steps

# %%
SGS.off()
SGS.power(-10)
SGS.frequency(11.725e9)
SGS.on()
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(False)
keithley_24.output(1)

appl_current(-2e-7)
#appl_TG(-10)
#magnet_x.field(0.23e-3)
#magnet_y.field(1.41e-3)
# sleep(1)

# station.snapshot(update=True);
exp = qc.new_experiment('IV-RF_f', sample_name=f'103-03_J2_27-26-30-31M(32G-33G-28G-29G)_1M_By@0.1mT{-I_range}')

#do1d(param_set, start, stop, num_points, delay, *param_meas)""
dataid = do1d(appl_current,-2e-7 ,2e-7, 101, 0.05,  meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()
keithley_24.output(0)
SGS.off()
appl_current(0)
plot_by_id(dataid)
# print(get_R_from_IV(dataid))
#print(get_R_from_IV_2(dataid))

# %%
SGS.off()
SGS.power(0)
SGS.frequency(3.87e9)
SGS.on()
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(False)
keithley_24.output(1)

appl_current(-1.2e-6)
#appl_TG(-10)
magnet_y.field(-10e-3)

#magnet_y.field(1.41e-3)
# sleep(1)

# station.snapshot(update=True);
exp = qc.new_experiment('Bx vs RF_f', sample_name='By vs RF_f_J2_3.87_-10dB')

#do1d(param_set, start, stop, num_points, delay, *param_meas)""
dataid = do2d(magnet_y.field, -10e-3, 10e-3,701, 1, appl_current,-1.2e-6 ,1.2e-6, 101, 0.05,  meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()
keithley_24.output(0)
SGS.off()
appl_current(0)
plot_by_id(dataid)
# print(get_R_from_IV(dataid))
#print(get_R_from_IV_2(dataid))

# %%
appl_current(0)
#appl_TG(0)
magnet_y.field(0)
sleep(10)
magnet_x.field(0)
sleep(10)
#appl_voltage_AC(0.004)
SGS.off()

# %% [markdown]
# ## IV vs Power Dependence

# %%
SGS.off()

# %%
SGS.power(-40)

# %%
SGS.off()

# %%
SGS.off()
SGS.power(-20)
SGS.frequency(5.9534e9)
SGS_frequency = SGS.frequency()
SGS.on()
keithley_2.averaging_count(3)
keithley_2.averaging_enabled(False)
keithley_24.output(1)

#magnet_x.field(15e-3)
#sleep(5)
I_range = 6e-6
appl_current(-I_range)
#appl_TG(-30)
sleep(2)

# station.snapshot(update=True);
exp = qc.new_experiment('IV-RF_p', sample_name=f'103-03_J2_27-26-30-31M(32G-33G-28G-29G)_1M_RF@{SGS_frequency*1e-9:.4f}GHz_By@0.1mT')

#do1d(param_set, start, stop, num_points, delay, *param_meas)

dataid = do2d(SGS.power,10, 15, 51, 0.1, appl_current,-I_range ,I_range, 301, 0.00001, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

SGS.off()
appl_current(0)
keithley_24.output()
plot_by_id(dataid)

# print(get_R_from_IV(dataid))
print(get_R_from_IV_2(dataid))
# Out:
# There is (are) already experiment(s) with the name of IV-RF_p and sample name of 103-03_J2_27-26-30-31M(32G-33G-28G-29G)_1M_RF@5.9534GHz_By@0.1mT in the database.
# Starting experimental run with id: 6523.
# first parameter:  47%|████▋     | 24/51 [02:59<03:21,  7.48s/it]
# An exception occured in measurement with guid: 6e28bca0-0000-0000-0000-018f7fe4e5f6;
# Traceback:
# Traceback (most recent call last):
#   File "C:\qcodes\sweeps2.py", line 52, in do2d
#     datasaver.add_result((param_set1, set_point1),
#   File "C:\Users\admin\AppData\Roaming\Python\Python39\site-packages\qcodes\dataset\measurements.py", line 229, in add_result
#     self.dataset._enqueue_results(results_dict)
#   File "C:\Users\admin\AppData\Roaming\Python\Python39\site-packages\qcodes\dataset\data_set.py", line 1282, in _enqueue_results
#     self.cache.add_data(new_results)
#   File "C:\Users\admin\AppData\Roaming\Python\Python39\site-packages\qcodes\dataset\data_set_cache.py", line 125, in add_data
#     ) = append_shaped_parameter_data_to_existing_arrays(
#   File "C:\Users\admin\AppData\Roaming\Python\Python39\site-packages\qcodes\dataset\data_set_cache.py", line 298, in append_shaped_parameter_data_to_existing_arrays
#     updated_write_status[meas_parameter]) = _merge_data(
#   File "C:\Users\admin\AppData\Roaming\Python\Python39\site-packages\qcodes\dataset\data_set_cache.py", line 327, in _merge_data
#     single_param_merged_data, new_write_status = _merge_data_single_param(
#   File "C:\Users\admin\AppData\Roaming\Python\Python39\site-packages\qcodes\dataset\data_set_cache.py", line 361, in _merge_data_single_param
#     (merged_data, new_write_status) = _insert_into_data_dict(
#   File "C:\Users\admin\AppData\Roaming\Python\Python39\site-packages\qcodes\dataset\data_set_cache.py", line 410, in _insert_into_data_dict
#     data = np.append(existing_values, new_values, axis=0)
#   File "<__array_function__ internals>", line 180, in append
#   File "c:\Users\admin\.conda\envs\qcodes\lib\site-packages\numpy\lib\function_base.py", line 5444, in append
#     return concatenate((arr, values), axis=axis)
#   File "<__array_function__ internals>", line 180, in concatenate
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[554], line 22
#      18 exp = qc.new_experiment('IV-RF_p', sample_name=f'103-03_J2_27-26-30-31M(32G-33G-28G-29G)_1M_RF@{SGS_frequency*1e-9:.4f}GHz_By@0.1mT')
#      20 #do1d(param_set, start, stop, num_points, delay, *param_meas)
# ---> 22 dataid = do2d(SGS.power,10, 15, 51, 0.1, appl_current,-I_range ,I_range, 301, 0.00001, meas_voltage_K2)
#      23 # dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
#      24 # ivvi.set_dacs_zero()
#      26 SGS.off()
#
# File C:\qcodes\sweeps2.py:52, in do2d(param_set1, start1, stop1, num_points1, delay1, param_set2, start2, stop2, num_points2, delay2, *param_meas)
#      50             for i, parameter in enumerate(param_meas):
#      51                 output[i][1] = parameter.get()
# ---> 52             datasaver.add_result((param_set1, set_point1),
#      53                                  (param_set2, set_point2),
#      54                                  *output)
#      55         param_set2.set(start2)
#      56 dataid = datasaver.run_id  # convenient to have for plotting
#
# File ~\AppData\Roaming\Python\Python39\site-packages\qcodes\dataset\measurements.py:229, in DataSaver.add_result(self, *res_tuple)
#     226 self._validate_result_shapes(results_dict)
#     227 self._validate_result_types(results_dict)
# --> 229 self.dataset._enqueue_results(results_dict)
#     231 if perf_counter() - self._last_save_time > self.write_period:
#     232     self.flush_data_to_database()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\qcodes\dataset\data_set.py:1282, in DataSet._enqueue_results(self, result_dict)
#    1277             new_results[st.name] = {
#    1278                 st.name: self._reshape_array_for_cache(st, result_dict[st])
#    1279             }
#    1281 if self._in_memory_cache:
# -> 1282     self.cache.add_data(new_results)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\qcodes\dataset\data_set_cache.py:125, in DataSetCache.add_data(self, new_data)
#     117 for param_name, single_param_dict in new_data.items():
#     118     expanded_data[param_name] = _expand_single_param_dict(
#     119         single_param_dict
#     120     )
#     122 (
#     123     self._write_status,
#     124     self._data
# --> 125 ) = append_shaped_parameter_data_to_existing_arrays(
#     126     self.rundescriber,
#     127     self._write_status,
#     128     self._data,
#     129     new_data=expanded_data
#     130 )
#     132 if not all(status is None for status in self._write_status.values()):
#     133     self._live = True
#
# File ~\AppData\Roaming\Python\Python39\site-packages\qcodes\dataset\data_set_cache.py:298, in append_shaped_parameter_data_to_existing_arrays(rundescriber, write_status, existing_data, new_data)
#     294     else:
#     295         shape = None
#     297     (merged_data[meas_parameter],
# --> 298      updated_write_status[meas_parameter]) = _merge_data(
#     299         existing_data_1_tree,
#     300         new_data_1_tree,
#     301         shape,
#     302         single_tree_write_status=write_status.get(meas_parameter),
#     303         meas_parameter=meas_parameter
#     304     )
#     305 return updated_write_status, merged_data
#
# File ~\AppData\Roaming\Python\Python39\site-packages\qcodes\dataset\data_set_cache.py:327, in _merge_data(existing_data, new_data, shape, single_tree_write_status, meas_parameter)
#     320     raise RuntimeError(
#     321         "Trying to add unexpected key to cache."
#     322         "The following keys were unexpected: "
#     323         f"{set(new_data.keys() - existing_data.keys())}"
#     324     )
#     326 new_write_status: int | None
# --> 327 single_param_merged_data, new_write_status = _merge_data_single_param(
#     328     existing_data.get(meas_parameter),
#     329     new_data.get(meas_parameter),
#     330     shape,
#     331     single_tree_write_status
#     332 )
#     333 if single_param_merged_data is not None:
#     334     subtree_merged_data[meas_parameter] = single_param_merged_data
#
# File ~\AppData\Roaming\Python\Python39\site-packages\qcodes\dataset\data_set_cache.py:361, in _merge_data_single_param(existing_values, new_values, shape, single_tree_write_status)
#     357 merged_data: np.ndarray | None
#     358 if (
#     359     existing_values is not None and existing_values.size != 0
#     360 ) and new_values is not None:
# --> 361     (merged_data, new_write_status) = _insert_into_data_dict(
#     362         existing_values, new_values, single_tree_write_status, shape=shape
#     363     )
#     364 elif new_values is not None:
#     365     (merged_data,
#     366      new_write_status) = _create_new_data_dict(
#     367         new_values,
#     368         shape
#     369     )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\qcodes\dataset\data_set_cache.py:410, in _insert_into_data_dict(existing_values, new_values, write_status, shape)
#     408 if shape is None or write_status is None:
#     409     try:
# --> 410         data = np.append(existing_values, new_values, axis=0)
#     411     except ValueError:
#     412         # we cannot append into a ragged array so make that manually
#     413         n_existing = existing_values.shape[0]
#
# File <__array_function__ internals>:180, in append(*args, **kwargs)
#
# File c:\Users\admin\.conda\envs\qcodes\lib\site-packages\numpy\lib\function_base.py:5444, in append(arr, values, axis)
#    5442     values = ravel(values)
#    5443     axis = arr.ndim-1
# -> 5444 return concatenate((arr, values), axis=axis)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
SGS.off()
SGS.power(-25)
SGS.frequency(5.226e9)
SGS.on()
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
keithley_24.output(1)

magnet_y.field(-8e-3)
sleep(60)
appl_current(-2e-7)
#appl_TG(-30)
sleep(2)

# station.snapshot(update=True);
exp = qc.new_experiment('IV vs power dependence', sample_name='IV vs PD_5.226_By:-8mT')

#do1d(param_set, start, stop, num_points, delay, *param_meas)

dataid = do2d(SGS.power,-25, 10, 101, 20, appl_current,-2e-7 ,2e-7, 101, 0.05, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()

SGS.off()
appl_current(0)
keithley_24.output()
plot_by_id(dataid)

# print(get_R_from_IV(dataid))
print(get_R_from_IV_2(dataid))

# %% [markdown]
# ### PD vs frequency_IV loop (not yet)

# %%
frequencies = [3.248, 3.387, 5.677]
power_levels = [-20, 0, 25]
     
SGS.off()
SGS.power(-20)
SGS.frequency(3.387e9)
SGS.on()
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
keithley_24.output(1)

appl_current(-2e-6)
#appl_TG(-10)
sleep(1)

for freq in frequencies:
    SGS.frequency(freq)
    for power_level in power_levels:
        SGS.power(power_level)

# station.snapshot(update=True);
exp = qc.new_experiment('IV vs power dependence', sample_name='IV vs PD_J2_3.387_m20')
dataid = do2d(SGS.power, 4, 8, 100, 2, appl_current, -1e-6, 1e-6, 101, 0.05, meas_voltage_K2)

 # 關閉設備，並在需要時列印或繪製結果
SGS.off()
appl_current(0)
keithley_24.output()
plot_by_id(dataid)
    
print(f"頻率：{freq} Hz，功率水平：{power_level} dB")
print(get_R_from_IV_2(dataid))

# %% [markdown]
# ## IV vs Vgate

# %%
appl_current(0)
appl_TG(0)
magnet_y.field(0)
sleep(10)
magnet_x.field(0)
sleep(10)
appl_voltage_AC(0.004)
SGS.off()

# %%
SGS.off()
SGS.power(25)
SGS.frequency(4.83e9)
SGS.on()
keithley_2.averaging_count(5)
keithley_2.averaging_enabled(True)
appl_current(-0.4e-7)
appl_current_AC(0.1e-10)

appl_TG(-10)
sleep(1)

# station.snapshot(update=True);
exp = qc.new_experiment('IV vs Vgate', sample_name='IV vs Vg')

dataid = do2d(appl_TG, -10, 10, 751, 0.5, appl_current, -0.4e-7, 0.4e-7, 101, 0.01, meas_voltage_AC_L1, meas_voltage_AC_L1_P, meas_voltage_K2)
# dataid = do1d(appl_current, 6e-6 , -6e-6, 251, 0.01, meas_voltage_K1)
# ivvi.set_dacs_zero()
SGS.off()
appl_current(0)
plot_by_id(dataid)
# print(get_R_from_IV(dataid))
#print(get_R_from_IV_2(dataid))

# %%
appl_current(0)
appl_TG(0)
magnet_y.field(0)
sleep(10)
magnet_x.field(0)
sleep(10)
appl_voltage_AC(0.004)
SGS.off()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Constants
k = 8.617333262145e-5  # Boltzmann constant in eV/K
E_a = 0.5  # Example value for the activation energy in eV
p_0 = 1.0  # Example value for p0

# Create an array of temperatures from 100 to 1000 K
temperatures = np.linspace(100, 1000, 50)

# Calculate 1/T
inverse_temperatures = 1 / temperatures

# Calculate ln(p)
ln_p = np.log(p_0) - (E_a / k) * inverse_temperatures

# Plotting
plt.figure(figsize=(8, 6))
plt.plot(inverse_temperatures, ln_p, marker='o', linestyle='-')
plt.xlabel('1/T (1/K)')
plt.ylabel('ln(p)')
plt.title('ln(p) vs 1/T for Hole Concentration')
plt.grid(True)
plt.show()
